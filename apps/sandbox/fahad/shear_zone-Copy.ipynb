# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
sp.init_printing()
import ipywidgets as ipw

# %% [markdown]
# # Fracture process segment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The crack path consists of three segments. The lower segment $x_\mathrm{L}$ represents the localized crack. It can be represented by a continuous curve, i.e. spline or by piecewise linear geometry. The upper segment $x_\mathrm{U}$ represents the uncracked zone. The segments in-between represents the fracture process zone FZP which has a fixed length $L^\mathrm{fps}$ and orientation $\theta$ related to the vertical direction $z$. The coordinates of the segment start $x^{\mathrm{fps}}_{ak}$ is implicitly considered to be in the state of peak tensile stress. The position of the tip of the segment is then given as
# \begin{align}
# x^{\mathrm{fps}}_{ak} = x^{\mathrm{tip}}_{an} + L^{\mathrm{fps}}
# \left[
# \begin{array}{c}
# -\sin(\theta) \\ \cos(\theta)
# \end{array}
# \right]
# \end{align}

# %%
theta = sp.symbols(r'\theta', nonnegative=True)
L_fps = sp.symbols(r'L_\mathrm{fps}', nonnegative=True)
ell = sp.symbols(r'\ell', nonnegative=True)

# %% [markdown]
# # Identify the rotation for given crack opening

# %% [markdown]
# Kinematics of the section based on the assumption
# that the right side of the shear zone rotates relatively
# to the fixed left side around an unknown position $x^{\mathrm{rot}}_{ak}$. The horizontal position of the center of rotation is assumed identical with the tip of the process zone segment $x^{\mathrm{tip}}_{ak}$, i.e.
# \begin{align}
# x^{\mathrm{rot}}_{0k} = x^{\mathrm{tip}}_{0k}
# \end{align}

# %% [markdown]
# The criterion of a crack reaching the strength is defined in strains. This brings about the possibility to circumvent the discussion on the bi-axial stress criterion. This can be seen in analogy to a compression test failure simulated as micro-cracking with cracks oriented in the loading direction.
# For this purpose, it is important to include the

# %%
phi, x_rot_1k = sp.symbols(
   r'phi, x^\mathrm{rot}_{1k}', nonegative=True
)
x_tip_0n = sp.symbols(r'x^{\mathrm{tip}}_{0n}')
x_tip_1n = sp.symbols(r'x^{\mathrm{tip}}_{1n}')
xi = sp.symbols('xi')
w = sp.Symbol('w', nonnegative=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
c_theta = sp.Symbol('c_theta')
s_theta = sp.Symbol('s_theta')

# %%
cs_theta = sp.Matrix([c_theta, s_theta])
cs_theta_ = sp.Matrix([sp.cos(theta), sp.sin(theta)])

# %%
t_vec = sp.Matrix([-s_theta, c_theta])
n_vec = sp.Matrix([c_theta, s_theta])
t_vec, n_vec
# Out:
# ⎛⎡-sₜₕₑₜₐ⎤  ⎡cₜₕₑₜₐ⎤⎞
# ⎜⎢       ⎥, ⎢      ⎥⎟
# ⎝⎣cₜₕₑₜₐ ⎦  ⎣sₜₕₑₜₐ⎦⎠

# %%
x_tip_an = sp.Matrix([x_tip_0n, x_tip_1n])
x_fps_ak = x_tip_an + L_fps * t_vec
x_rot_0k = x_fps_ak[0]
x_rot_0k
# Out:
# -L_\mathrm{fps}⋅sₜₕₑₜₐ + x_{0n}__{\mathrm{tip}}

# %% [markdown]
#  * $t$ is the line vector of the fracture propagation segment
#  * $n$ is a vector normal to the fracture propagation segment

# %%
x_tip_ak = x_tip_an + ell * t_vec
x_rot_ak = sp.Matrix([x_rot_0k, x_rot_1k])
x_tip_an, x_tip_ak, x_rot_ak, x_fps_ak
# Out:
# ⎛⎡x_{0n}__{\mathrm{tip}}⎤  ⎡-\ell⋅sₜₕₑₜₐ + x_{0n}__{\mathrm{tip}}⎤  ⎡-L_\mathr
# ⎜⎢                      ⎥, ⎢                                     ⎥, ⎢
# ⎝⎣x_{1n}__{\mathrm{tip}}⎦  ⎣\ell⋅cₜₕₑₜₐ + x_{1n}__{\mathrm{tip}} ⎦  ⎣
#
# m{fps}⋅sₜₕₑₜₐ + x_{0n}__{\mathrm{tip}}⎤  ⎡-L_\mathrm{fps}⋅sₜₕₑₜₐ + x_{0n}__{\m
#                                       ⎥, ⎢
#     x_{1k}__\mathrm{rot}              ⎦  ⎣L_\mathrm{fps}⋅cₜₕₑₜₐ + x_{1n}__{\ma
#
# athrm{tip}}⎤⎞
#            ⎥⎟
# thrm{tip}} ⎦⎠

# %% [markdown]
# The final position must be on a line parallel to $t$ in
# the distance $w$
# \begin{align}
# x^{\mathrm{tip},\varphi}_{ak} = x^{\mathrm{tip}}_{ak} + w \, n_{ak} + \xi \, t_{ak}
# \end{align}

# %%
x_phi_xi_ak = x_tip_ak + w * n_vec + xi * t_vec
x_phi_xi_ak
# Out:
# ⎡-\ell⋅sₜₕₑₜₐ + cₜₕₑₜₐ⋅w - sₜₕₑₜₐ⋅ξ + x_{0n}__{\mathrm{tip}}⎤
# ⎢                                                           ⎥
# ⎣\ell⋅cₜₕₑₜₐ + cₜₕₑₜₐ⋅ξ + sₜₕₑₜₐ⋅w + x_{1n}__{\mathrm{tip}} ⎦

# %% [markdown]
# Vector connecting rotation center with the curent crack tip point on the fixed plate $k$
# \begin{align}
# v^{\mathrm{tip}}_{ak} = x^{\mathrm{tip}}_{ak} - x^{\mathrm{rot}}_{ak}
# \end{align}

# %%
v_tip_ak = (x_tip_ak - x_rot_ak)
v_tip_ak
# Out:
# ⎡            L_\mathrm{fps}⋅sₜₕₑₜₐ - \ell⋅sₜₕₑₜₐ            ⎤
# ⎢                                                           ⎥
# ⎣\ell⋅cₜₕₑₜₐ - x_{1k}__\mathrm{rot} + x_{1n}__{\mathrm{tip}}⎦

# %% [markdown]
# Vector connecting the rotation center with the current crak tip point on the rotated plate
# \begin{align}
# v^{\mathrm{tip},\varphi}_{ak}
# = x^{\mathrm{tip},\varphi}_{ak} - x^{\mathrm{rot}}_{ak}
# \end{align}

# %%
v_phi_xi_ak = (x_phi_xi_ak - x_rot_ak)
v_phi_xi_ak
# Out:
# ⎡            L_\mathrm{fps}⋅sₜₕₑₜₐ - \ell⋅sₜₕₑₜₐ + cₜₕₑₜₐ⋅w - sₜₕₑₜₐ⋅ξ
# ⎢
# ⎣\ell⋅cₜₕₑₜₐ + cₜₕₑₜₐ⋅ξ + sₜₕₑₜₐ⋅w - x_{1k}__\mathrm{rot} + x_{1n}__{\mathrm{t
#
#     ⎤
#     ⎥
# ip}}⎦

# %% [markdown]
# The distance $|RP| = R-P$ must be equal to $|RQ| = R-Q$. Let us express the squares of the distances
# \begin{align}
#  v^{\mathrm{tip}}_{a}  v^{\mathrm{tip}}_{a} &=
#  v^{\mathrm{tip}, \varphi}_{b}  v^{\mathrm{tip, \varphi}}_{b}  \\
#  \| \boldsymbol{v}^{\mathrm{tip}} \|^2
# &=
#  \| \boldsymbol{v}^{\mathrm{tip}, \varphi} \|^2
# \end{align}

# %%
v_tip_ak_2 = v_tip_ak.T *  v_tip_ak
v_phi_xi_ak_2 = v_phi_xi_ak.T * v_phi_xi_ak

# %% [markdown]
# The equal distance can be used to resolve the unknown slip parameter $s$

# %%
Eq_xi_ = sp.Eq(v_tip_ak_2[0], v_phi_xi_ak_2[0])
Eq_xi_
# Out:
#                                      2
# (L_\mathrm{fps}⋅sₜₕₑₜₐ - \ell⋅sₜₕₑₜₐ)  + (\ell⋅cₜₕₑₜₐ - x_{1k}__\mathrm{rot} +
#
#                         2
#  x_{1n}__{\mathrm{tip}})  = (L_\mathrm{fps}⋅sₜₕₑₜₐ - \ell⋅sₜₕₑₜₐ + cₜₕₑₜₐ⋅w -
#
#          2
# sₜₕₑₜₐ⋅ξ)  + (\ell⋅cₜₕₑₜₐ + cₜₕₑₜₐ⋅ξ + sₜₕₑₜₐ⋅w - x_{1k}__\mathrm{rot} + x_{1n
#
#                   2
# }__{\mathrm{tip}})

# %%
xi_solved = sp.solve(Eq_xi_, xi)[0]
xi_solved
# Out:
#
#                      2              2              2
# L_\mathrm{fps}⋅sₜₕₑₜₐ  - \ell⋅cₜₕₑₜₐ  - \ell⋅sₜₕₑₜₐ  + cₜₕₑₜₐ⋅x_{1k}__\mathrm{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                           ____________________________________
#                                          ╱               2       4
# rot} - cₜₕₑₜₐ⋅x_{1n}__{\mathrm{tip}} - ╲╱  L_\mathrm{fps} ⋅sₜₕₑₜₐ  - 2⋅L_\math
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#                    2       2                               4
# rm{fps}⋅\ell⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ  - 2⋅L_\mathrm{fps}⋅\ell⋅sₜₕₑₜₐ  - 2⋅L_\mathrm{fps
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#         3                                          3
# }⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅w - 2⋅L_\mathrm{fps}⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅w + 2⋅L_\mathrm{fps}⋅cₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#          2                                                      2
# ₜₐ⋅sₜₕₑₜₐ ⋅x_{1k}__\mathrm{rot} - 2⋅L_\mathrm{fps}⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅x_{1n}__{\ma
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#                  2       4         2       2       2       2       4
# thrm{tip}} + \ell ⋅cₜₕₑₜₐ  + 2⋅\ell ⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ  + \ell ⋅sₜₕₑₜₐ  - 2⋅\ell⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#       3                                     3
# cₜₕₑₜₐ ⋅x_{1k}__\mathrm{rot} + 2⋅\ell⋅cₜₕₑₜₐ ⋅x_{1n}__{\mathrm{tip}} - 2⋅\ell⋅
# ──────────────────────────────────────────────────────────────────────────────
#         2         2
#   cₜₕₑₜₐ  + sₜₕₑₜₐ
#
# ______________________________________________________________________________
#              2                                            2
# cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅x_{1k}__\mathrm{rot} + 2⋅\ell⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅x_{1n}__{\mathrm{t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#              4  2           2       2  2           2
# ip}} - cₜₕₑₜₐ ⋅w  - 2⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ ⋅w  + 2⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅w⋅x_{1k}__\mathrm{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#                2                                         2
# rot} - 2⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅w⋅x_{1n}__{\mathrm{tip}} + cₜₕₑₜₐ ⋅x_{1k}__\mathrm{rot
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#  2           2                                                     2
# }  - 2⋅cₜₕₑₜₐ ⋅x_{1k}__\mathrm{rot}⋅x_{1n}__{\mathrm{tip}} + cₜₕₑₜₐ ⋅x_{1n}__{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#              2         4  2           3                                  3
# \mathrm{tip}}  - sₜₕₑₜₐ ⋅w  + 2⋅sₜₕₑₜₐ ⋅w⋅x_{1k}__\mathrm{rot} - 2⋅sₜₕₑₜₐ ⋅w⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________
#
# _{1n}__{\mathrm{tip}}
# ──────────────────────

# %%
dxi_dcs = xi_solved.diff(cs_theta)
dcs_dtheta = cs_theta_.diff(theta)
dxi_theta = (dxi_dcs.T * dcs_dtheta)[0,0] ##question

# %%
dxi_dx_rot_1k = xi_solved.diff(x_rot_1k) ##question

# %%
py_vars = ('theta', 'x_rot_1k', 'x_tip_0n', 'x_tip_1n', 'L_fps', 'ell', 'w')
map_py2sp = {py_var : globals()[py_var] for py_var in py_vars}
sp_vars = tuple(map_py2sp[py_var] for py_var in py_vars)
sp_vars ##question
# Out:
# (\theta, x_{1k}__\mathrm{rot}, x_{0n}__{\mathrm{tip}}, x_{1n}__{\mathrm{tip}},
#  L_\mathrm{fps}, \ell, w)

# %%
get_cs = sp.lambdify(sp_vars, cs_theta_)
get_xi_cs = sp.lambdify(sp_vars + (c_theta, s_theta), xi_solved)
def get_xi(*params):
    cs_ = get_cs(*params)
    xi_ = get_xi_cs(*(params + tuple(cs_)))
    return xi_[0]
get_xi_cs
# Out:
# <function _lambdifygenerated(Dummy_175, Dummy_174, Dummy_173, Dummy_172, Dummy_177, Dummy_176, w, c_theta, s_theta)>

# %%
params = 0, 1, 0, 0, 0.1, 0.1, 0.1
cs_vals = get_cs(*params).T[0]
cs_params = params + tuple(cs_vals)
get_xi(*params)
# Out:
# 0.005572809000084167

# %%
x_phi_xi_ak
# Out:
# ⎡-\ell⋅sₜₕₑₜₐ + cₜₕₑₜₐ⋅w - sₜₕₑₜₐ⋅ξ + x_{0n}__{\mathrm{tip}}⎤
# ⎢                                                           ⎥
# ⎣\ell⋅cₜₕₑₜₐ + cₜₕₑₜₐ⋅ξ + sₜₕₑₜₐ⋅w + x_{1n}__{\mathrm{tip}} ⎦

# %%
get_x_phi_cs_ak = sp.lambdify(sp_vars + (c_theta, s_theta, xi), x_phi_xi_ak)
def get_x_phi_ak(*params):
    xi = get_xi_cs(*params)
    return get_x_phi_cs_ak(*(params + (xi,)))
get_x_tip_an = sp.lambdify(sp_vars + (c_theta, s_theta), x_tip_an)
get_x_tip_ak = sp.lambdify(sp_vars + (c_theta, s_theta), x_tip_ak)
get_x_rot_ak = sp.lambdify(sp_vars + (c_theta, s_theta), x_rot_ak)
get_x_fps_ak = sp.lambdify(sp_vars + (c_theta, s_theta), x_fps_ak)
x_fps_ak
# Out:
# ⎡-L_\mathrm{fps}⋅sₜₕₑₜₐ + x_{0n}__{\mathrm{tip}}⎤
# ⎢                                               ⎥
# ⎣L_\mathrm{fps}⋅cₜₕₑₜₐ + x_{1n}__{\mathrm{tip}} ⎦

# %%
get_x_fps_ak(*(params + (0,1)))
# Out:
# array([[-0.1],
#        [ 0. ]])

# %%
fig, ax = plt.subplots(1,1,figsize=(6,3),tight_layout=True)

import traits.api as tr

class SZModel(tr.HasTraits):

    H = tr.Float(1.0)
    L = tr.Float(4.0)
    B = tr.Float(0.2)
    # define the free parameters as traits with default, min and max values
    theta = tr.Float(0.8, min=0, max=np.pi/2, interact=True)
    x_rot_1k = tr.Float(0.5, min=0, max=1, interact=True)
    x_tip_0n = tr.Float(2, min=0, max=5, interact=True)
    x_tip_1n = tr.Float(0.1, min=0, max=1, interact=True)
    L_fps = tr.Float(0.2, min=0, max=0.5, interact=True)
    ell = tr.Float(0.05, min=0, max=0.1, interact=True)
    w = tr.Float(0.03, min=0, max=0.2, interact=True)
    
    params_ = tr.Tuple(0.8, 1, 0, 0.5, 0.5, 0.1)

    def set_all_points(self, *plot_params):
        c_theta, s_theta = get_cs(*plot_params )
        params = plot_params + (c_theta[0], s_theta[0])
        self.x_rot_ak_ = get_x_rot_ak(*params)
        self.x_tip_an_ = get_x_tip_an(*params)
        self.x_tip_ak_ = get_x_tip_ak(*params)
        self.x_phi_ak_ = get_x_phi_ak(*params)
        self.x_fps_ak_ = get_x_fps_ak(*params)

    def plot_all_points(self, w):
        ax.axis('equal')
        ax.set_ylim(ymin=0,ymax=self.H)
        ax.set_xlim(xmin=0,xmax=self.L)
        plot_params = (self.params_ + (w,))
        self.set_all_points(*plot_params)
        self.x_rot_ak_p, = ax.plot(*self.x_rot_ak_, marker='o', color='blue')
        self.x_tip_an_p, = ax.plot(*self.x_tip_an_, marker='o', color='green')
        self.x_tip_ak_p, = ax.plot(*self.x_tip_ak_, marker='o', color='orange')
        self.x_phi_ak_p, = ax.plot(*self.x_phi_ak_, marker='o', color='orange')
        self.x_fps_ak_p, = ax.plot(*self.x_fps_ak_, marker='o', color='red')
        self.red_line_p, = ax.plot(*np.c_[self.x_tip_an_, self.x_fps_ak_],
            color='red')
        self.blue_line_p, = ax.plot(*np.c_[self.x_fps_ak_, self.x_rot_ak_],
            color='blue')
        print(self.x_rot_ak_)

    def update_plot(self, **values):
        print('updating')
        param_vals = tuple(values[py_var] for py_var in py_vars)
        self.set_all_points(*param_vals)
        self.x_rot_ak_p.set_data(*self.x_rot_ak_)
        self.x_tip_an_p.set_data(*self.x_tip_an_)
        self.x_tip_ak_p.set_data(*self.x_tip_ak_)
        self.x_phi_ak_p.set_data(*self.x_phi_ak_)
        self.x_fps_ak_p.set_data(*self.x_fps_ak_)
        self.red_line_p.set_data(*np.c_[self.x_tip_an_, self.x_fps_ak_])
        self.blue_line_p.set_data(*np.c_[self.x_fps_ak_, self.x_rot_ak_])

        
    n_steps = tr.Int(50)
    def get_ipw_sliders(self):
        traits = self.traits(interact=True)
        vals = self.trait_get(interact=True)
        return { name : ipw.FloatSlider(
            value=vals[name],
            min=trait.min,
            max=trait.max,
            step=trait.max/self.n_steps,
            description=r'\(%s\)' % map_py2sp[name].name)
            for (name, trait) in traits.items()
        }
        
    def interact(self):
        self.plot_all_points(0.1)
        sliders = self.get_ipw_sliders()
        out = ipw.interactive_output(self.update_plot,sliders);
        layout = ipw.Layout(grid_template_columns='1fr 1fr')
        sliders_list = [sliders[py_var] for py_var in py_vars]
        grid = ipw.GridBox(sliders_list, layout=layout)
        box = ipw.VBox([grid, out])
        display(box)

kinem = SZModel()
kinem.interact()
# Out:
# updating
# VBox(children=(GridBox(children=(FloatSlider(value=0.8, description='\\(\\theta\\)', max=1.5707963267948966, s…

# %% [markdown]
# # Rotation angle and rotation matrix
#
# Given the initial vector $v_{ak}^\mathrm{tip}$ and the rotated
# vector $v_{ak}^\mathrm{\varphi}$, the $\cos$ and $\sin$
# needed for the rotation matrix is expressed as
# \begin{align}
# | v_{k}^\mathrm{tip} | = \sqrt{v_{ak}^\mathrm{tip} v_{ak}^\mathrm{tip}}
# \end{align}
# \begin{align}
# \cos(\varphi)_k = \frac{v_{ak}^\mathrm{tip} v_{bk}^\varphi} {| v_{k}^\mathrm{tip} |}
# &=
# \frac{v_{ak}^\mathrm{tip} v_{bk}^\varphi} {\sqrt{v_{ak}^\mathrm{tip} v_{ak}^\mathrm{tip}}}
# \end{align}
# the derivative with respect to $\theta$ and $x_ak^\mathrm{rot}$
# \begin{align}
# \cos(\varphi)_{k,\theta\zeta} = \frac{v_{ak}^\mathrm{tip} v_{bk}^\varphi} {| v_{k}^\mathrm{tip} |}
# &=
# \frac{v_{ak}^\mathrm{tip} v_{bk}^\varphi} {\sqrt{v_{ak}^\mathrm{tip} v_{ak}^\mathrm{tip}}}
# \end{align}

# %%
sp.Function('fa_1')(theta, x_rot_1k)
# Out:
# fa₁(\theta, x_{1k}__\mathrm{rot})

# %%
a_1, a_2, b_1, b_2 = sp.symbols('a_1, a_2, b_1, b_2')
a_mtx = sp.Matrix([a_1, a_2])
b_mtx = sp.Matrix([b_1, b_2])

# %%
a_norm = sp.sqrt(a_mtx.T * a_mtx)
a_norm
# Out:
#              1/2
# ⎛⎡  2     2⎤⎞
# ⎝⎣a₁  + a₂ ⎦⎠

# %%
dot_ab = a_mtx.T * b_mtx
dot_ab
# Out:
# [a₁⋅b₁ + a₂⋅b₂]

# %%
sp.simplify((dot_ab * a_norm**(-1))**2)
# Out:
# ⎡               2⎤
# ⎢(a₁⋅b₁ + a₂⋅b₂) ⎥
# ⎢────────────────⎥
# ⎢     2     2    ⎥
# ⎣   a₁  + a₂     ⎦

# %%
v_tip_ak_mtx = sp.MatrixSymbol(r'(v_{ak}^\mathrm{rot})', 2, 1)
v_phi_ak_mtx = sp.MatrixSymbol(r'v_{ak}^{\varphi}', 2, 1)
(v_tip_ak_mtx.T * v_phi_ak_mtx).diff(theta)
# Out:
# 𝟘

# %%
v_tip_ak_ = sp.symbols(r'v_ak^{\mathrm{tip}}')

# %% [markdown]
# The primary kinematic variables are introduced as the vertical displacement on the left hand side $v$ and the rotation of the left section $\varphi$.

# %%
get_v_phi_xi_ak = sp.lambdify(sp_vars + (xi,), v_phi_xi_ak)
def get_v_phi_ak(*sp_vars):
    xi_ = get_xi(*sp_vars)
    return get_v_phi_xi_ak(*(sp_vars + (xi_,)))

# %%
cos_xi_phi = (v_tip_ak.T * v_phi_xi_ak)[0,0] / len_v_tip_ak_2[0,0] ##len_v_tip_ak_2???
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-af58e58121a9> in <module>
# ----> 1 cos_xi_phi = (v_tip_ak.T * v_phi_xi_ak)[0,0] / len_v_tip_ak_2[0,0] ##len_v_tip_ak_2???
#
# NameError: name 'len_v_tip_ak_2' is not defined

# %%
cos_xi_phi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-259da5ead7cb> in <module>
# ----> 1 cos_xi_phi
#
# NameError: name 'cos_xi_phi' is not defined

# %%
sin_xi_phi = (v_tip_ak[0] * v_phi_xi_ak[1] - v_tip_ak[1] * v_phi_xi_ak[0]) / len_v_tip_ak_2[0,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-ce4255b89449> in <module>
# ----> 1 sin_xi_phi = (v_tip_ak[0] * v_phi_xi_ak[1] - v_tip_ak[1] * v_phi_xi_ak[0]) / len_v_tip_ak_2[0,0]
#
# NameError: name 'len_v_tip_ak_2' is not defined

# %%
sin_xi_phi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-53ce8bf3e76c> in <module>
# ----> 1 sin_xi_phi
#
# NameError: name 'sin_xi_phi' is not defined

# %%
d_cos_theta = cos_xi_phi.diff(theta) + cos_xi_phi.diff(xi) * d_slip_theta #Question
d_cos_x_rot_1k = cos_xi_phi.diff(x_rot_1k) + cos_xi_phi.diff(xi) * d_slip_x_rot_1k #Question
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-5c177bf41773> in <module>
# ----> 1 d_cos_theta = cos_xi_phi.diff(theta) + cos_xi_phi.diff(xi) * d_slip_theta #Question
#       2 d_cos_x_rot_1k = cos_xi_phi.diff(x_rot_1k) + cos_xi_phi.diff(xi) * d_slip_x_rot_1k #Question
#
# NameError: name 'cos_xi_phi' is not defined

# %%
d_sin_theta = sin_xi_phi.diff(theta) + sin_xi_phi.diff(xi) * d_slip_theta
d_sin_x_rot_1k = sin_xi_phi.diff(x_rot_1k) + sin_xi_phi.diff(xi) * d_slip_x_rot_1k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-45c6ac81d370> in <module>
# ----> 1 d_sin_theta = sin_xi_phi.diff(theta) + sin_xi_phi.diff(xi) * d_slip_theta
#       2 d_sin_x_rot_1k = sin_xi_phi.diff(x_rot_1k) + sin_xi_phi.diff(xi) * d_slip_x_rot_1k
#
# NameError: name 'sin_xi_phi' is not defined

# %%
c_phi, s_phi = sp.symbols(r'\cos(\varphi), \sin(\varphi)')

# %% [markdown]
# # Rotation matrix

# %% [markdown]
# The rotation matrix is then defined as
# \begin{align}
# \Phi &=
# \left[
# \begin{array}{cc}
# \cos{\varphi} & - \sin{\varphi} \\
# \sin{\varphi} & cos{\varphi}
# \end{array}
# \right]
# \end{align}

# %%
Phi = sp.Matrix(
        [[c_phi, -s_phi],
         [s_phi, c_phi]], dtype=np.float_)
Phi
# Out:
# ⎡\cos(\varphi)  -\sin(\varphi)⎤
# ⎢                             ⎥
# ⎣\sin(\varphi)  \cos(\varphi) ⎦

# %%
Phi.diff(c_phi), Phi.diff(s_phi)
# Out:
# ⎛⎡1  0⎤  ⎡0  -1⎤⎞
# ⎜⎢    ⎥, ⎢     ⎥⎟
# ⎝⎣0  1⎦  ⎣1  0 ⎦⎠

# %% [markdown]
# # Rotated plate

# %% [markdown]
# The left plate is rotated around $x^{\mathrm{rot}}_a$
# \begin{align}
# x^1_{Lb} = \Phi_{ab} (x^0_{La} - x^{\mathrm{rot}}_a ) + x^{\mathrm{rot}}_a
# \end{align}

# %%
x_rot_0, x_rot_1 = sp.symbols(r'x^{\mathrm{rot}}_0, x^{\mathrm{rot}}_1')
x_rot = sp.Matrix([[x_rot_0], [x_rot_1]])
x_L_0, x_L_1 = sp.symbols(r'x^{\mathrm{L}}_0, x^{\mathrm{L}}_1')
x_L = sp.Matrix([[x_L_0], [x_L_1]])

# %%
x1_a = sp.simplify(Phi * (x_L - x_rot) + x_rot)
x1_a
# Out:
# ⎡\cos(\varphi)⋅(x_0__{\mathrm{L}} - x_0__{\mathrm{rot}}) - \sin(\varphi)⋅(x_1_
# ⎢
# ⎣\cos(\varphi)⋅(x_1__{\mathrm{L}} - x_1__{\mathrm{rot}}) + \sin(\varphi)⋅(x_0_
#
# _{\mathrm{L}} - x_1__{\mathrm{rot}}) + x_0__{\mathrm{rot}}⎤
#                                                           ⎥
# _{\mathrm{L}} - x_0__{\mathrm{rot}}) + x_1__{\mathrm{rot}}⎦

# %% [markdown]
# **TODO:** Define the chained derivatives for the rotated coordinate
# \begin{align}
# x^{1}_{a,\theta \zeta} = x^{1}_{,\zeta} + x^{1}_{a, c} c_{,\theta \zeta}
# \end{align}

# %% [markdown]
# # Crack opening and sliding

# %% [markdown]
# The displacement at the ligament
# \begin{align}
# u_{Lb} &= x^1_{Lb} - x^0_{Lb}
# \end{align}

# %%
u_L = x1_a - x_L
u_L
# Out:
# ⎡\cos(\varphi)⋅(x_0__{\mathrm{L}} - x_0__{\mathrm{rot}}) - \sin(\varphi)⋅(x_1_
# ⎢
# ⎣\cos(\varphi)⋅(x_1__{\mathrm{L}} - x_1__{\mathrm{rot}}) + \sin(\varphi)⋅(x_0_
#
# _{\mathrm{L}} - x_1__{\mathrm{rot}}) - x_0__{\mathrm{L}} + x_0__{\mathrm{rot}}
#
# _{\mathrm{L}} - x_0__{\mathrm{rot}}) - x_1__{\mathrm{L}} + x_1__{\mathrm{rot}}
#
# ⎤
# ⎥
# ⎦

# %% [markdown]
# Both coordinates of the center of rotation $X^\mathrm{rot}_a$ are unknown. Let us assume for a while that the horizontal coordinate is fixed. Then we can find the vertical coordinate by applying a kinematic constraint requiring that the horizontal displacement at the center of rotation $u_{L0}$ must be zero, i.e.

# %% [markdown]
# \begin{align}
# u_0( x^\mathrm{rot}_1 ) = 0
# \end{align}

# %%
u_L0 = u_L[0].subs(x_L_0, x_rot_0)
u_L0
# Out:
# -\sin(\varphi)⋅(x_1__{\mathrm{L}} - x_1__{\mathrm{rot}})

# %% [markdown]
# ## Crack path

# %% [markdown]
# Let us now consider a rotated configuration of the right plate around $x_{ak}^{\mathrm{rot}}$. Further , let us assume that the rotation angle $\varphi$ would induce the critical crack opening $w_\mathrm{f}$ at the point $x^{\mathrm{tip}}_{ak}$

# %% [markdown]
# By transforming the $u_{Lb}$ to in-line and out-of-line components
# \begin{align}
#  w_{Lr} = T_{Lar} u_{La}
# \end{align}

# %% [markdown]
# By applying the constitutive relation
# \begin{align}
# s_{Ls} = \mathcal{S}_{Ls}(w_{Lr})
# \end{align}

# %% [markdown]
# Transformation to the global coordinate system
# \begin{align}
# \sigma_{La} = T_{Las} s_{Ls}
# \end{align}

# %% [markdown]
# Normal force is obtained by evaluating the integral
# \begin{align}
# N = \int_{0}^{H} \sigma_{0}(x_1) \; \mathrm{d}x
# \end{align}

# %% [markdown]
# The vertical position of the center of rotation is obtained by requiring the equality of compressive and tensile force within the cross section
# \begin{align}
# N(X_1) = 0
# \end{align}

# %% [markdown]
# At the same tome the shear force gets calculated as
# \begin{align}
# Q =
# \int_{\Gamma} \sigma_1(x_1) \; \mathrm{d}x
# \end{align}

# %% [markdown]
# and the moment around the position $x = 0$ and $y = \hat{X}_1$
# \begin{align}
# M(x = 0, y = \hat{X}_1) =
# \int \sigma_1 x_0 \; \mathrm{d}x
# \end{align}

# %% [markdown]
# Require that at the crack tip, the crack opening $w$ is equal to critical crack opening
# \begin{align}
#  \hat{w} = w_1(\hat{X}_a)
# \end{align}
# \begin{align}
# w_\mathrm{cr} = \frac{ f_\mathrm{t} } { E_\mathrm{c} } L_{c}
# \end{align}

# %% [markdown]
# where $L_\mathrm{c}$ represents the characteristic length.

# %% [markdown]
# W, N, M - Q * sz.L

# %% [markdown]
# Global equations are defined as
# \begin{align}
#  M - Q L &= 0 \\
#  N &= 0 \\
#  w_{\mathrm{cr}} - w_{\mathrm{tip}} &= 0
# \end{align}

# %% [markdown]
# # Level set crack path

# %% [markdown]
# Consider a crack path defined by a level set function
# \begin{align}
# \gamma( x_a ) = 0
# \end{align}
# This function consists of three branches. The existing crack $gamma_0( x_a ) = 0$ which ends at a point $x_a^{\mathrm{tip}}$

# %% [markdown]
# On the other hand, assuming

# %% [markdown]
# Localization length is used to transform the crack opening at the crack tip
# to the tensile strain within that zone.

# %% [markdown]
# # Shear zone domain
# The geometry of the shear zone is defined as length $L$, height $H$ and width $B$. They are defined numerically for the running example as

# %%
L_, H_, B_ =  100, 60, 20

# %% [markdown]
# The corner coordinates are stored in an array $x_{aC}$ where $a \in (0,1)$ is the dimension index and $C \in (0,1,2,3)$ is the global corner index

# %%
x_aC = np.array([[0, L_, L_, 0], 
                 [0, 0, H_, H_]], dtype=np.float_)
x_Ca = x_aC.T

# %% [markdown]
# The lines delimiting the shear zone are defined by an index map $C_{Li}$ with $L \in (0,1,2,3)$ denoting the line and $i \in (0,1)$ the local node index defining a line.

# %%
C_Li = np.array([[0,1],[1,2],[2,3],[3,0]], dtype=np.int_).T
C_Li
# Out:
# array([[0, 1, 2, 3],
#        [1, 2, 3, 0]])

# %% [markdown]
# **Example:** With this zone definition, the lines can be ordered to an array $x_{iCa}$ using the index operator as follows.

# %%
x_iCa = x_aC.T[C_Li]
np.einsum('iMa->aiM', x_iCa)
# Out:
# array([[[  0., 100., 100.,   0.],
#         [100., 100.,   0.,   0.]],
#
#        [[  0.,   0.,  60.,  60.],
#         [  0.,  60.,  60.,   0.]]])

# %% [markdown]
# # Crack path
# The crack path is defined along the nodes $x_{aI}$ with $a \in (0,1)$ representing the dimension index and $I \in 1 \ldots n_I$ defining the global node index.

# %% [markdown]
# A starting example of a crack geometry is defined as follows

# %%
x1_Ia = np.array([
    [20, 0],
    [25, 10]
])
x10_Ia = np.array([
       [20.,  0.],
       [21.,  6.],
       [23., 12.],
       [24., 16.],
       [27., 22.],
       [40., 40.],
       [45., 44.],
       [51., 46.],
       [60., 48.],
       [65., 49.]], dtype=np.float_)

# %% [markdown]
# For convenience, let us define a plotting function to visualize a crack path within the studied zone. Not that the  crack nodes are ordered so that no topology needs to be defined for plotting.

# %% [markdown]
# But to stay general, let us introduce the topological mapping specifying the association between a crack segment number $L \in 1 \ldots n_I-1$ as an index map $I_{Li}$.

# %%
def get_I_Li(x_Ia):
    N_I = np.arange(len(x_Ia))
    I_Li = np.array([N_I[:-1], N_I[1:]], dtype=np.int_).T
    return I_Li

# %% [markdown]
# The nodal coordinates rearranged into an array accessible via a line segment index $L$ and the local segment node $i \in (0,1)$ is defined as.

# %%
def get_x_Ja(x_Ia, x_Ca, n_J):
    x_J_1 = np.linspace(x_Ia[-1,1], x_Ca[-1,1], n_J)
    return np.c_[x_Ia[-1,0]*np.ones_like(x_J_1), x_J_1]

# %%
get_x_Ja(x1_Ia, x_Ca, 5)
# Out:
# array([[25. , 10. ],
#        [25. , 22.5],
#        [25. , 35. ],
#        [25. , 47.5],
#        [25. , 60. ]])

# %% [markdown]
# The line vector $v_{La}$ is obtained by subtracting the first node $i=0$ from the second node $i=1$
# \begin{align}
# v_{La} = x_{L1a} - x_{L0a}
# \end{align}

# %%
def get_n_vec_La(x_Ia):
    x_Lia = x_Ia[get_I_Li(x_Ia)]
    n_vec_La = x_Lia[:,1,:] - x_Lia[:,0,:]
    return n_vec_La

# %%
def get_norm_n_vec_L(x_Ia):
    n_vec_La = get_n_vec_La(x_Ia)
    return np.sqrt(np.einsum('...a,...a->...', n_vec_La, n_vec_La))

# %% [markdown]
# normalize the vector to a unit length
# \begin{align}
#  \hat{v}_{La} = \frac{v_{La}}{| v |_L}
# \end{align}

# %%
def get_normed_n_vec_La(x_Ia):
    return np.einsum('...a,...->...a',
        get_n_vec_La(x_Ia), 1. / get_norm_n_vec_L(x_Ia))

# %% [markdown]
# Using the Levi-Civita symbol
# \begin{align}
# \epsilon_{abc}
# \end{align}
# and an out-of-plane vector $z_a = [0,0,1]$

# %%
EPS = np.zeros((3, 3, 3), dtype='f')
EPS[(0, 1, 2), (1, 2, 0), (2, 0, 1)] = 1
EPS[(2, 1, 0), (1, 0, 2), (0, 2, 1)] = -1
Y = np.array([0,0,-1], dtype=np.float_)

# %% [markdown]
# we obtain the normal vector to the line as
# \begin{align}
# \hat{t}_{La} = \hat{n}_{Lb} z_c \epsilon_{abc}
# \end{align}

# %% [markdown]
# \begin{align}
# \hat{o}_{bLa} = [\hat{n}_{La}, \hat{t}_{La}]
# \end{align}
#
# \begin{align}
# \hat{o}_{Lab} = \hat{o}_{bLa}
# \end{align}

# %% [markdown]
# The function with the parameters defining the current crack path is defined as follows

# %%
def get_o_base_Lab(x_Ia):
    I_Li = get_I_Li(x_Ia)
    x_Lia = x_Ia[I_Li]
    n_vec_La = x_Lia[:,1,:] - x_Lia[:,0,:]
    norm_n_vec_L = np.sqrt(np.einsum('...a,...a->...', n_vec_La, n_vec_La))
    normed_n_vec_La = np.einsum('...a,...->...a',
        n_vec_La, 1. / norm_n_vec_L)
    t_vec_La = np.einsum('ijk,...j,k->...i', 
                      EPS[:-1,:-1,:], normed_n_vec_La, Y);
    o_base_bLa = np.array([t_vec_La, normed_n_vec_La])
    o_base_Lab = np.einsum('bLa->Lab', o_base_bLa)
    return o_base_Lab

# %% [markdown]
# # Prepare Integration along the path
# Get midpoints of the line segments along the crack path
# and construct a vector of the orthonormal base $\hat{o}_{Lab}$ starting a the midpoints as

# %%
def get_x_n_ejaM(x_Ia, plot_scale=1):
    I_Li=get_I_Li(x_Ia)
    o_base_Lab = get_o_base_Lab(x_Ia)
    x_Lia = x_Ia[I_Li]
    x_n0_Mea = np.einsum(
        'e,Ma->Mae',np.ones((2,)), np.sum(x_Lia, axis=1)/2)
    x_n_jMea = np.array(
        [x_n0_Mea, x_n0_Mea + plot_scale*o_base_Lab]
    )
    return np.einsum('jMae->ejaM', x_n_jMea)

# %%
def plot_sz_geo(ax, x_Ia, x_Ca=x_Ca):
    x_aI = x_Ia.T
    x_aiC = np.einsum('Cia->aiC', x_Ca[C_Li])
    x_Ja = get_x_Ja(x_Ia, x_Ca, 5)
    ax.plot(*x_aiC, color='black');
    ax.plot(*x_aI, lw=2, color='blue');
    ax.plot(*x_Ja.T, lw=2, color='gray');

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
plot_sz_geo(ax,x10_Ia, x_Ca)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Define a function that plots nodal values along the shear crack in normal direction

# %%
def plot_o_base_Lab(ax, x_Ia):
    I_Li = get_I_Li(x_Ia)
    plot_sz_geo(ax, x_Ia)
    x_n_ejaM = get_x_n_ejaM(x_Ia, plot_scale=3.0)
    x_n_eajM = np.einsum('ejaM->eajM', x_n_ejaM)
    ax.plot(*x_n_eajM.reshape(-1,2,len(I_Li)), color='orange',lw=3);
fig, ax = plt.subplots(1,1,figsize=(10,6))
plot_o_base_Lab(ax, x10_Ia)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Deformed configuration

# %%
u2_a = np.array([1, 0], dtype=np.float_)

# %%
def translate(x_Ia, u_a):
    return x_Ia[:,:] + u_a[np.newaxis,:]

# %%
def get_rot_mtx(phi):
    return np.array(
        [[np.cos(phi), -np.sin(phi)],
         [np.sin(phi), np.cos(phi)]], dtype=np.float_)

# %%
CR = (x_Ca[1] + x_Ca[2])/2
def rotate(x_Ia, phi):
    rot_mtx = get_rot_mtx(phi)
    u_Ib = np.einsum(
        'ab,...b->...a',
        rot_mtx, x_Ia - CR
    )
    return u_Ib + CR

# %%
U_a = np.array([0,0,0])

# %%
def get_moved_Ia(x_Ia, U_a):
    u_a = U_a[:2]
    phi = U_a[2]
    return rotate(x_Ia=translate(x_Ia, u_a), phi=phi)

# %%
def plot_moved(ax, x_Ia, x_Ca, U_a):
    plot_sz_geo(ax,x_Ia=x_Ia,x_Ca=x_Ca)
    plot_sz_geo(ax,x_Ia=get_moved_Ia(x_Ia, U_a), 
                x_Ca=get_moved_Ia(x_Ca,U_a))

# %%
fig, ax = plt.subplots(1,1,figsize=(10,8))
plot_moved(ax, x10_Ia, x_Ca, np.array([-1,0,0]))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Define the

# %%
U1_a = np.array([-0.01, 0, 0])
u_Ia = get_moved_Ia(x_Ia=x1_Ia, U_a=U1_a) - x1_Ia

# %%
def get_u_Lb(x_Ia, U_a):
    I_Li=get_I_Li(x_Ia) 
    u_Ia = get_moved_Ia(x_Ia, U_a)-x_Ia
    u_Lia = u_Ia[I_Li]
    u_La = np.sum(u_Lia, axis=1)/2
    o_base_Lab = get_o_base_Lab(x_Ia)
    u_Lb = np.einsum(
        'La,Lab->Lb',u_La, o_base_Lab
    )
    return u_Lb

# %%
u_Lb = get_u_Lb(x1_Ia, U1_a)

# %% [markdown]
# Get a vector oriented normally to the crack path scaled by the supplied array $v_M$
# \begin{align}
# x_{aiM} =
# \end{align}

# %%
def get_x_nv_ejaM(x_Ia, U_a, plot_scale=1):
    I_Li = get_I_Li(x_Ia)
    u_Lb = get_u_Lb(x_Ia, U_a)
    o_base_Lab = get_o_base_Lab(x_Ia)
    x_Lia = x_Ia[I_Li]
    x_n0_Mea = np.einsum(
        'e,Ma->Mae',np.ones((2,)), np.sum(x_Lia, axis=1)/2)
    uo_base_Lab = plot_scale*np.einsum(
        'Lb, Lab->Lab', u_Lb, o_base_Lab
    )
    x_n_jMea = np.array(
        [x_n0_Mea, x_n0_Mea + uo_base_Lab]
    )
    return np.einsum('jMae->ejaM', x_n_jMea)

# %%
def plot_uo_base_Lab(ax, x_Ia, U_a):
    plot_sz_geo(ax, x_Ia)
    x_n_ejaM = get_x_nv_ejaM(x_Ia, U_a)
    x_n_eajM = np.einsum('ejaM->eajM', x_n_ejaM)
    I_Li = get_I_Li(x_Ia)
    ax.plot(*x_n_eajM.reshape(-1,2,len(I_Li)), color='orange',lw=3);
U_a = np.array([-10,0,0.0])
fig, ax = plt.subplots(1,1,figsize=(10,6))
plot_moved(ax, x1_Ia, x_Ca, U_a)
plot_uo_base_Lab(ax, x1_Ia, U_a)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Stress evaluation
# Given the crack opening $w$ and slip $s$ along the crack path
# \begin{align}
# \eta(x_a) =0
# \end{align}
# The normal vector with respect to the crack path can be evaluated as a gradient
# \begin{align}
# \eta(x_a)_{,b}
# \end{align}

# %% [markdown]
# material laws for slip and for crack opening are defined independently as
# \begin{align}
# \mathcal{T} := (w,s) \rightarrow (\sigma, \tau)
# \end{align}

# %% [markdown]
# **Crack opening law**: Define a function with an embedded fracture energy $G_\mathrm{f}$

# %%
w, f_t, G_f, S_max = sp.symbols(
    'w, f_t, G_f, S_max'
)
f_w = f_t * sp.exp(-f_t*w/G_f)
S_w = sp.Piecewise(
    (S_max, w < 0), 
    (0, w <= 0), 
    (f_w, w > 0)
)
 
S_w
# Out:
# ⎧   Sₘₐₓ     for w < 0
# ⎪
# ⎪    0       for w ≤ 0
# ⎪
# ⎨    -fₜ⋅w
# ⎪    ──────
# ⎪     G_f
# ⎪fₜ⋅ℯ        otherwise
# ⎩

# %%
d_S_w = S_w.diff(w)
d_S_w
# Out:
# ⎧      0        for w ≤ 0
# ⎪
# ⎪      -fₜ⋅w
# ⎪      ──────
# ⎨   2   G_f
# ⎪-fₜ ⋅ℯ
# ⎪─────────────  otherwise
# ⎪     G_f
# ⎩

# %%
co_law_data = dict(f_t=3, G_f=0.5, S_max=1e+9)

# %%
get_S_w = sp.lambdify(w, S_w.subs(co_law_data), 'numpy' )
get_d_S_w = sp.lambdify(w, d_S_w.subs(co_law_data), 'numpy' )

# %%
w_max_expr = (sp.solve(f_w + f_w.diff(w) * w, w)[0]).subs(co_law_data)
w_max = np.float_(w_max_expr) * 10

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(9,3)) 
fig.subplots_adjust(hspace=0.5)
w_data = np.linspace(0, w_max, 100)
ax1.plot(w_data, get_S_w(w_data),color='black')
ax1.set_xlabel(r'$w\;\;\mathrm{[mm]}$'); ax1.set_ylabel(r'$\sigma\;\;\mathrm{[MPa]}$'); 
ax1.set_title('crack opening law')
ax2.plot(w_data, get_d_S_w(w_data), color='black')
ax2.set_xlabel(r'$s\;\;\mathrm{[mm]}$'); ax2.set_ylabel(r'$\mathrm{d}\sigma/\mathrm{d}w\;\;\mathrm{[MPa/mm]}$');
ax2.set_title('bond stiffness');
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# **Bond-slip law:** An example bond model is defined as a piecewise linear function exhibiting softening. The nonlinear algorithm requires the evaluation of $\mathrm{d}\tau/\mathrm{d}s$ which is delivered symbolically using the `diff` method. The function is defined by three data points
# $(\tau_1,s_1), (\tau_2,s_2), (\tau_3,s_3)$.

# %%
s, tau_1, s_1, tau_2, s_2, tau_3, s_3 = sp.symbols(
    r's, tau_1, s_1, tau_2, s_2, tau_3, s_3 '
)
tau_s = sp.Piecewise(
    (tau_1/s_1 * s, s < s_1), 
    (tau_1 + (tau_2-tau_1)/(s_2-s_1)*(s-s_1), s <= s_2), 
    (tau_2 + (tau_3-tau_2)/(s_3-s_2)*(s-s_2), s > s_2)
)
d_tau_s = tau_s.diff(s)

# %% [markdown]
# The dictionary of values specifying the data points is defined as

# %%
bond_data = dict(tau_1=2, s_1=0.1, tau_2=1, s_2=0.4, tau_3=0.8, s_3=1.6)

# %%
get_tau_s_plus = sp.lambdify(s, tau_s.subs(bond_data), 'numpy' )
get_d_tau_s_plus = sp.lambdify(s, d_tau_s.subs(bond_data), 'numpy' )

# %%
def get_tau_s(s):
    signs = np.sign(s)
    return signs * get_tau_s_plus(signs * s)
def get_d_tau_s(s):
    signs = np.sign(s)
    return signs * get_d_tau_s_plus(signs * s)

# %%
s_max = float(s_3.subs(bond_data))
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,3.5)) 
fig.subplots_adjust(hspace=0.5)
s_data = np.linspace(-s_max, s_max, 100)
ax1.plot(s_data, get_tau_s(s_data),color='black')
ax1.set_xlabel(r'$s\;\;\mathrm{[mm]}$'); ax1.set_ylabel(r'$\tau\;\;\mathrm{[MPa]}$'); 
ax1.set_title('bond-slip law')
ax2.plot(s_data, get_d_tau_s(s_data), color='black')
ax2.set_xlabel(r'$s\;\;\mathrm{[mm]}$'); ax2.set_ylabel(r'$\mathrm{d}\tau/\mathrm{d}s\;\;\mathrm{[MPa/mm]}$');
ax2.set_title('bond stiffness');
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
def get_S_b(u_a):
    sig = get_S_w(u_a[...,0])
    tau = get_tau_s(u_a[...,1])
    return np.einsum('b...->...b', np.array([sig, tau], dtype=np.float_))

# %%
x3_Ia = np.array([
    [20, 0],
    [20,10],
    [25,10]
])
U3_a = np.array([0, .1, 0])

# %%
def get_S_La( x_Ia, U_a ):
    u_Lb = get_u_Lb(x_Ia, U_a)
    S_Lb = get_S_b(u_Lb)
    S_La = np.einsum('Lb,Lab->La',S_Lb, get_o_base_Lab(x_Ia))
    return S_La

# %%
def get_F_La(x_Ia, U_a):
    S_La = get_S_La(x_Ia, U_a)
    F_La = np.einsum('La,L->La',S_La,get_norm_n_vec_L(x_Ia))
    return F_La

# %%
def get_M(x_Ia, U_a):
    I_Li = get_I_Li(x_Ia)
    x_Lia = x_Ia[I_Li]
    x_La = np.sum(x_Lia, axis=1)/2
    F_La = get_F_La(x_Ia, U_a)
    M_L = x_La[:,0] * F_La[:,1] - x_La[:,1] * F_La[:,0]
    return np.sum(M_L, axis=0)

# %%
def get_F_a(x_Ia, U_a):
    F_La = get_F_La(x_Ia, U_a)
    F_a = np.sum(F_La, axis=0)
    return F_a

# %%
def get_FM_a(x_Ia, U_a):
    I_Li = get_I_Li(x_Ia)
    x_Lia = x_Ia[I_Li]
    x_La = np.sum(x_Lia, axis=1)/2
    F_La = get_F_La(x_Ia, U_a)
    M_L = x_La[:,0] * F_La[:,1] - x_La[:,1] * F_La[:,0]
    F_a = np.sum(F_La, axis=0)
    M = np.sum(M_L, axis=0)
    return np.hstack([F_a, M])

# %%
get_FM_a(x3_Ia, U3_a)
# Out:
# array([  0.        ,  28.23217454, 585.22392718])

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
plot_moved(ax, x3_Ia, x_Ca, U3_a)
plot_uo_base_Lab(ax, x3_Ia, U3_a)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# The previous elementary examples served for the calculation of the reaction corresponding to the given global displacement state.
# By converting the task to the case that we prescribe the shear force
# \begin{align}
#  Q = \bar{Q}
# \end{align}

# %% [markdown]
# The considered loading prescribes either $Q$ or $W$. Then, $M = Q L$ and $N = 0$
# \begin{align}
# Q &= \bar{Q} \\
# M &= \bar{Q} L \\
# N &= 0
# \end{align}
# The above equations represent the
# \begin{align}
# P_{R} &= [N, Q, M] \\
# U_{S} &= [U, V, \Phi] \\
# \end{align}
# \begin{align}
#  P_{R}(U_{S}) = \bar{P}
# \end{align}

# %% [markdown]
# Express the $P_{R}(y_a, x_{Ia}, U_{S})$ in terms of the crack tip coordinates $y_{a}$

# %% [markdown]
# # Verification 1 - Tension

# %% [markdown]
# Put the initial crack at the bottom. Let the $N = 0, U= 0$ and prescribe $\bar{Q}$. Then $\bar{M} = \bar{Q} L$.

# %%
U4_a = np.array([0,0.1,0], dtype=np.float)
x4_Ia = np.array([[20,  0], [20, 10]], dtype=np.float)

# %%
N, Q, M = get_FM_a(x4_Ia, U4_a)
R_M = Q * L_ - M

# %%
M, Q * L_
# Out:
# (399.9999999999984, 1999.9999999999923)

# %%
R_M
# Out:
# 1599.9999999999939

# %% [markdown]
# # Shear stress in FPS

# %%
Q_, H_, B_ = sp.symbols('Q, H, B', nonnegative=True)
z_ = sp.Symbol('z', positive=True)
a_, b_, c_ = sp.symbols('a, b, c')
z_fps_ = sp.Symbol(r'z^{\mathrm{fps}}', nonnegative=True)

# %%
tau_z = a_*z_**2 + b_*z_ + c_

# %%
eqs = {
    tau_z.subs(z_,0),
    tau_z.subs(z_,H_)
}

# %%
ac_subs = sp.solve(eqs, {a_,c_})
ac_subs
# Out:
# ⎧   -b       ⎫
# ⎨a: ───, c: 0⎬
# ⎩    H       ⎭

# %%
Tau_z_fn = tau_z.subs(ac_subs)
Tau_z_fn
# Out:
#          2
#       b⋅z
# b⋅z - ────
#        H

# %%
Q_int = sp.integrate(Tau_z_fn,(z_,z_fps_,H_))
Q_int
# Out:
#  2                        2                      3
# H ⋅b   b⋅z__{\mathrm{fps}}    b⋅z__{\mathrm{fps}}
# ──── - ──────────────────── + ────────────────────
#  6              2                     3⋅H

# %%
b_subs = sp.solve({Q_ - B_*Q_int}, {b_})
b_subs
# Out:
# ⎧                           6⋅H⋅Q                         ⎫
# ⎪b: ──────────────────────────────────────────────────────⎪
# ⎨     ⎛ 3                        2                      3⎞⎬
# ⎪   B⋅⎝H  - 3⋅H⋅z__{\mathrm{fps}}  + 2⋅z__{\mathrm{fps}} ⎠⎪
# ⎩                                                         ⎭

# %%
Tau_z_ff = Tau_z_fn.subs(b_subs)
Tau_z_ff
# Out:
#
#                        6⋅H⋅Q⋅z
# ────────────────────────────────────────────────────── - ─────────────────────
#   ⎛ 3                        2                      3⎞     ⎛ 3
# B⋅⎝H  - 3⋅H⋅z__{\mathrm{fps}}  + 2⋅z__{\mathrm{fps}} ⎠   B⋅⎝H  - 3⋅H⋅z__{\math
#
#         2
#    6⋅Q⋅z
# ─────────────────────────────────
#         2                      3⎞
# rm{fps}}  + 2⋅z__{\mathrm{fps}} ⎠

# %%
Tau_z_fps = Tau_z_ff.subs(z_,z_fps_)
sp.simplify(Tau_z_fps)
# Out:
#                6⋅Q⋅z__{\mathrm{fps}}
# ───────────────────────────────────────────────────
#   ⎛ 2                                            2⎞
# B⋅⎝H  + H⋅z__{\mathrm{fps}} - 2⋅z__{\mathrm{fps}} ⎠

# %%
get_tau_z_fps = sp.lambdify(
    (z_fps_, Q_, H_, B_), Tau_z_fps, 'numpy'
)

# %%
H_val = 200
B_val = 100
Q_val = np.linspace(0,100000,100)
z_fps_arr = np.linspace(0, H_val*0.98, 100)
tau_arr = get_tau_z_fps(z_fps_arr, Q_val, H_val, B_val)
fig, ax = plt.subplots(1,1,figsize=(8,4))
ax.plot(tau_arr, z_fps_arr);
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Principal stress directions in FPS

# %% [markdown]
# The corresponding tensile stress at this position which must be perpendicular to the crack propagation
# \begin{align}
# \sigma^{fps}_3 = f_t
# \end{align}

# %% [markdown]
# The stresses in the global co-ordinates are expressed as:
# \begin{align}
# \sigma_{xz} =
# \left[
# \begin{array}{cc}
# \sigma_{xx} & \tau_{xz} \\
# \tau_{zx} & \sigma_{zz}
# \end{array}
# \right] =
# \left[
# \begin{array}{cc}
# \sigma_{x} & \tau^\mathrm{fps} \\
# \tau^\mathrm{fps} & \sigma_{z}
# \end{array}
# \right]
# \end{align}

# %% [markdown]
# In our case $\sigma_z = 0$ as the specimen is uniaxially loaded therefore, the stress will be depicted as follows:
# The stresses in the global co-ordinates are expressed as:
# \begin{align}
# \sigma_{xz} =
# \left[
# \begin{array}{cc}
# \sigma_{xx} & \tau_{xz} \\
# \tau_{zx} & 0
# \end{array}
# \right] =
# \left[
# \begin{array}{cc}
# \sigma_{x} & \tau^\mathrm{fps} \\
# \tau^\mathrm{fps} & 0
# \end{array}
# \right]
# \end{align}
# $\sigma_x, \tau_{fps}, \sigma_z$ represents the stress in x-direction, shear stress in fracture process segment and stress in vertical direction respectively.

# %% [markdown]
# <img src="farfieldstress.png" width="500"/>

# %%
r = sp.Symbol('r', nonnegative = True)
theta = sp.Symbol(r'\theta', nonnegative = True)
K_I = sp.Symbol('K_I', nonnegative = True)
K_II = sp.Symbol('K_{II}', nonnegative = True)
T = sp.Symbol('T', nonnegative = True)
sigma_x =  sp.Symbol(r'\sigma_x', nonnegative = True)
sigma_z =  sp.Symbol(r'\sigma_z', nonnegative = True)
tau_fps = sp.Symbol(r'\tau_\mathrm{fps}')
a = sp.Symbol('a', nonnegative = True)
beta = sp.Symbol(r'\beta', nonnegative = True)
tau_fps
# Out:
# \tau_\mathrm{fps}

# %%
sigma_xz = sp.Matrix([[sigma_x, tau_fps],
                     [tau_fps, 0]])
#sigma_x0 = sigma_xz.subs(sigma_z,0)
sigma_xz#, sigma_x0
# Out:
# ⎡     \sigmaₓ       \tau_\mathrm{fps}⎤
# ⎢                                    ⎥
# ⎣\tau_\mathrm{fps}          0        ⎦

# %%
P_xz, D_xz = sigma_xz.diagonalize()
P_xz, D_xz
# Out:
# ⎛
# ⎜
# ⎜⎡            -2⋅\tau_\mathrm{fps}                            -2⋅\tau_\mathrm{
# ⎜⎢──────────────────────────────────────────────  ────────────────────────────
# ⎜⎢             _________________________________               _______________
# ⎜⎢            ╱        2                      2               ╱        2
# ⎜⎢\sigmaₓ + ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}    \sigmaₓ - ╲╱  \sigmaₓ  + 4⋅\
# ⎜⎢
# ⎜⎣                      1                                               1
# ⎜
# ⎝
#
#                      ⎡             _________________________________
#                      ⎢            ╱        2                      2
# fps}              ⎤  ⎢\sigmaₓ   ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}
# ──────────────────⎥  ⎢─────── - ────────────────────────────────────
# __________________⎥  ⎢   2                       2
#                 2 ⎥, ⎢
# tau_\mathrm{fps}  ⎥  ⎢
#                   ⎥  ⎢
#                   ⎦  ⎢                                                \sigmaₓ
#                      ⎢                      0                         ───────
#                      ⎣                                                   2
#
#                                       ⎤⎞
#                                       ⎥⎟
#                                       ⎥⎟
#               0                       ⎥⎟
#                                       ⎥⎟
#                                       ⎥⎟
#      _________________________________⎥⎟
#     ╱        2                      2 ⎥⎟
#   ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}  ⎥⎟
# + ────────────────────────────────────⎥⎟
#                    2                  ⎦⎠

# %%
sp.simplify(P_xz* D_xz * P_xz**(-1))
# Out:
# ⎡     \sigmaₓ       \tau_\mathrm{fps}⎤
# ⎢                                    ⎥
# ⎣\tau_\mathrm{fps}          0        ⎦

# %% [markdown]
# ## Representation of Far field stress in terms of Stress Intensity factors
# In this implementation, the far field stresses are represented in  terms of Stress Intensity factors (SIFs) where $K_I$ represents mode I and $K_{II}$ depicts mode II. This terminology of measuring stresses in SIFs for external stress acting in uniaxial direction is shown as:
# \begin{gather*}
# K_I = \sigma_x \sqrt{\pi a}\sin^2 \beta  \\
# K_{II} = \sigma_x \sqrt{\pi a}\sin\beta \cos\beta
# \end{gather*}
# The positive sign of $K_I$ highlights stress as tension where negative sign shows compression. Similarly, negative sign of $K_{II}$ represents stress in opposite direction. $\beta$ represents the angle of crack orientation with respect to the vertical direction and $a$ represents the length of crack as depicted in figure. In the case of pure mode I failure, $\beta$ is $90°$ whereas for failure along pure mode II $\beta = 0°$

# %% [markdown]
# The figure above shows stresses in the vicinity of crack tip. $\theta$ depicts crack propagation angle and $r$ represents the radius of fracture propagation segment.

# %%
s_b, c_b = sp.symbols('s_b, c_b')
s_b
# Out:
# s_b

# %%
K_I = sigma_x * sp.sqrt(sp.pi * a) * sp.sin(beta)**2
K_II  = sigma_x * sp.sqrt(sp.pi * a) * sp.cos(beta) * sp.sin(beta)
K_I, K_II
# Out:
# ⎛                 2                                            ⎞
# ⎝√π⋅\sigmaₓ⋅√a⋅sin (\beta), √π⋅\sigmaₓ⋅√a⋅sin(\beta)⋅cos(\beta)⎠

# %%
params = {beta:45*np.pi/180}

# %%
K_I_ = K_I.subs(params)
K_II_ = K_II.subs(params)
K_I_, K_II_
# Out:
# (0.5⋅√π⋅\sigmaₓ⋅√a, 0.5⋅√π⋅\sigmaₓ⋅√a)

# %% [markdown]
# ## Maximum Stress Theory
# This theory was given by Sih and Erdogan. It is based on the two dimensional stresses acting on the vicinity of the crack. These stresses are given in the figure below. Moreover, they are represented as:
# \begin{align}
# \label{eq:sigrr}
# \sigma_{rr} &= \frac{1}{\sqrt{2 \pi r}}\left( K_I \left( \cos \frac{\theta}{2}\left(1 + \sin^2 \frac{\theta}{2}\right)\right) + K_{II}\left(\sin \frac{\theta}{2}\left(1 -
# 3 \sin^2 \frac{\theta}{2} \right) \right) \right) + T \cos^2 \theta
# \end{align}
# \begin{align}
# \label{eq:sigtt}
# \sigma_{\theta\theta}
# & = \frac{1}{\sqrt{2 \pi r}}\left( K_I \left( \cos^3 \frac{\theta}{2} \right) - K_{II}\left(3 \sin \frac{\theta}{2} \cos^2 \frac{\theta}{2} \right) \right) + T \sin^2 \theta
# \end{align}
# \begin{align}
# \label{eq:sigtr}
# \sigma_{r\theta}
# & = \frac{1}{\sqrt{2 \pi r}}\left( K_I \left(\sin \frac{\theta}{2} \cos^2 \frac{\theta}{2} \right) + K_{II}\left(\cos \frac{\theta}{2}\left(1 - 3 \sin^2 \frac{\theta}{2} \right) \right) \right) + T \sin \theta \cos \theta
# \end{align}
# For simplicity T-Stress is neglected.

# %%
## Representation of sin and cos components as s_t and c_t for simplicity.
s_t, c_t = sp.symbols('s_t,c_t')
s_t_ = sp.sin(theta + beta.subs(params))
c_t_ = sp.cos(theta + beta.subs(params))
s_tb, c_tb = sp.symbols('s_tb, c_tb')
s_tb
# Out:
# s_tb

# %%
c_thebe = sp.Symbol(r'c_{\theta \beta}')
s_thebe = sp.Symbol(r's_{\theta \beta}')
cs_thebe = sp.Matrix([c_thebe, s_thebe])
cs_thebe_ = sp.Matrix([c_t_, s_t_])
cs_thebe_
# Out:
# ⎡cos(\theta + 0.785398163397448)⎤
# ⎢                               ⎥
# ⎣sin(\theta + 0.785398163397448)⎦

# %%
cs_theta
# Out:
# ⎡cₜₕₑₜₐ⎤
# ⎢      ⎥
# ⎣sₜₕₑₜₐ⎦

# %%
sigma_rr = 1/sp.sqrt(2 * sp.pi *r) * (K_I_*cs_theta[0]*(1 + (cs_theta[1])**2) \
                                      + (K_II_*cs_theta[1])*(1 - 3*(cs_theta[1])**2)) #+ T*(c_t)**2
#s_rr = sigma_rr.subs(c_t, c_t_).subs(s_t, s_t_)
#s_rr
sigma_rr
# Out:
#    ⎛                         ⎛      2    ⎞                            ⎛
# √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1⎠ + 0.5⋅√π⋅\sigmaₓ⋅√a⋅sₜₕₑₜₐ⋅⎝1 - 3⋅s
# ──────────────────────────────────────────────────────────────────────────────
#                                        2⋅√π⋅√r
#
#      2⎞⎞
# ₜₕₑₜₐ ⎠⎠
# ────────

# %%
sigma_tt = 1/sp.sqrt(2 * sp.pi *r) * (K_I_*(cs_theta[0])**3 \
                                      - (K_II_*(3*cs_theta[1]*(cs_theta[0])**2))) #+ T*s_t**2
#s_tt = sigma_tt.subs(c_t, c_t_).subs(s_t, s_t_)
#s_tt
sigma_tt
# Out:
#    ⎛                        3                           2       ⎞
# √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ  - 1.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⎠
# ─────────────────────────────────────────────────────────────────
#                              2⋅√π⋅√r

# %%
sigma_rt = 1/sp.sqrt(2 * sp.pi *r) * ((K_I_*(cs_theta[1]*(cs_theta[0])**2)) \
                                      + ((K_II_*cs_theta[0])*(1 - 3*(cs_theta[1])**2))) #+ T*s_t*c_t
#s_rt = sigma_rt.subs(c_t, c_t_).subs(s_t, s_t_)
#s_rt
sigma_rt
# Out:
#    ⎛                        2                                   ⎛            2
# √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ + 0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ⋅⎝1 - 3⋅sₜₕₑₜₐ
# ──────────────────────────────────────────────────────────────────────────────
#                                     2⋅√π⋅√r
#
# ⎞⎞
# ⎠⎠
# ──

# %%
sigma = sp.Matrix([[sigma_rr, sigma_rt],
                     [sigma_rt, sigma_tt]])
sigma
# Out:
# ⎡   ⎛                         ⎛      2    ⎞                            ⎛
# ⎢√2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1⎠ + 0.5⋅√π⋅\sigmaₓ⋅√a⋅sₜₕₑₜₐ⋅⎝1 - 3⋅
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                       2⋅√π⋅√r
# ⎢
# ⎢      ⎛                        2                                   ⎛
# ⎢   √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ + 0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ⋅⎝1 - 3⋅sₜₕ
# ⎢   ──────────────────────────────────────────────────────────────────────────
# ⎣                                       2⋅√π⋅√r
#
#       2⎞⎞     ⎛                        2                                   ⎛
# sₜₕₑₜₐ ⎠⎠  √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ + 0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ⋅⎝1
# ─────────  ───────────────────────────────────────────────────────────────────
#                                                2⋅√π⋅√r
#
#    2⎞⎞               ⎛                        3                           2
# ₑₜₐ ⎠⎠            √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ  - 1.5⋅√π⋅\sigmaₓ⋅√a⋅cₜₕₑₜₐ ⋅sₜ
# ──────            ────────────────────────────────────────────────────────────
#                                                2⋅√π⋅√r
#
#           2⎞⎞⎤
# - 3⋅sₜₕₑₜₐ ⎠⎠⎥
# ─────────────⎥
#              ⎥
#              ⎥
#     ⎞        ⎥
# ₕₑₜₐ⎠        ⎥
# ─────        ⎥
#              ⎦

# %%
R = sp.Matrix([[cs_thebe[0], -cs_thebe[1]],
              [cs_thebe[1],   cs_thebe[0]]])
R, R.T
# Out:
# ⎛⎡c_{\theta \beta}  -s_{\theta \beta}⎤  ⎡c_{\theta \beta}   s_{\theta \beta}⎤⎞
# ⎜⎢                                   ⎥, ⎢                                   ⎥⎟
# ⎝⎣s_{\theta \beta}  c_{\theta \beta} ⎦  ⎣-s_{\theta \beta}  c_{\theta \beta}⎦⎠

# %%
#s_t1 = sp.sin(theta) / 2
#c_t1 = sp.cos(theta) / 2
#s = sigma.subs(s_t,s_t1).subs(c_t,c_t1)
s = sigma
sigma_ = R * s * R.T #.subs(s_t,s_t_).subs(c_t,c_t_) #transformation into global stress matrix
sig = sp.simplify(sigma_) 
sig
# Out:
# ⎡              ⎛                          ⎛
# ⎢√2⋅\sigmaₓ⋅√a⋅⎝- cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝-cₜₕₑₜₐ⋅s_{\theta \beta}⋅(0.5⋅cₜₕₑₜ
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢               ⎛                          ⎛
# ⎢ √2⋅\sigmaₓ⋅√a⋅⎝- cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅c_{\theta \beta}⋅(0.5⋅cₜₕₑₜ
# ⎢ ────────────────────────────────────────────────────────────────────────────
# ⎣
#
#                                    ⎛                              2      ⎞⎞
# ₐ - 1.5⋅sₜₕₑₜₐ) + c_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ  + 0.5⎠⎠ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                    ⎛                              2      ⎞⎞
# ₐ - 1.5⋅sₜₕₑₜₐ) + s_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ  + 0.5⎠⎠ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  ⎛                          ⎛                              2
# c_{\theta \beta}⋅⎝- cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ  +
# ──────────────────────────────────────────────────────────────────────────────
#  2⋅√r
#
#                  ⎛                        ⎛                              2
# c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅c_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ  + 0
# ──────────────────────────────────────────────────────────────────────────────
# 2⋅√r
#
#     ⎞                    ⎛           ⎛      2    ⎞              ⎛        2
#  0.5⎠ + c_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1⎠ - 0.5⋅sₜₕₑₜₐ⋅⎝3⋅sₜₕₑₜₐ  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞                    ⎛           ⎛      2    ⎞              ⎛        2    ⎞⎞
# .5⎠ + s_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1⎠ - 0.5⋅sₜₕₑₜₐ⋅⎝3⋅sₜₕₑₜₐ  - 1⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞⎞⎞⎞                ⎛                        ⎛
# ⎠⎠⎠⎠  √2⋅\sigmaₓ⋅√a⋅⎝cₜₕₑₜₐ⋅c_{\theta \beta}⋅⎝-cₜₕₑₜₐ⋅s_{\theta \beta}⋅(0.5⋅cₜ
# ────  ────────────────────────────────────────────────────────────────────────
#
#
# ⎞⎞                   ⎛                        ⎛
# ⎠⎠     √2⋅\sigmaₓ⋅√a⋅⎝cₜₕₑₜₐ⋅c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅c_{\theta \beta}⋅(0.5⋅cₜ
# ──     ───────────────────────────────────────────────────────────────────────
#
#
#                                       ⎛                              2      ⎞⎞
# ₕₑₜₐ - 1.5⋅sₜₕₑₜₐ) + c_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ  + 0.5⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                       ⎛                              2      ⎞⎞
# ₕₑₜₐ - 1.5⋅sₜₕₑₜₐ) + s_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ  + 0.5⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     ⎛                          ⎛
#  + s_{\theta \beta}⋅⎝- cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ
# ──────────────────────────────────────────────────────────────────────────────
#      2⋅√r
#
#                     ⎛                        ⎛                              2
#  + s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅c_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ - 1.5⋅sₜₕₑₜₐ
# ──────────────────────────────────────────────────────────────────────────────
#     2⋅√r
#
# 2      ⎞                    ⎛           ⎛      2    ⎞              ⎛        2
#   + 0.5⎠ + c_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1⎠ - 0.5⋅sₜₕₑₜₐ⋅⎝3⋅sₜₕₑₜₐ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#      ⎞                    ⎛           ⎛      2    ⎞              ⎛        2
# + 0.5⎠ + s_{\theta \beta}⋅⎝0.5⋅cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1⎠ - 0.5⋅sₜₕₑₜₐ⋅⎝3⋅sₜₕₑₜₐ  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    ⎞⎞⎞⎞⎤
# - 1⎠⎠⎠⎠⎥
# ───────⎥
#        ⎥
#        ⎥
#  ⎞⎞⎞⎞  ⎥
# 1⎠⎠⎠⎠  ⎥
# ─────  ⎥
#        ⎦

# %%
P_rt, D_rt = sig.diagonalize()
P_rt, D_rt
#s_t_ = sp.sin(theta + beta.subs(params))
#c_t_ = sp.cos(theta + beta.subs(params))
#s_t_
# Out:
# ⎛⎡
# ⎜⎢
# ⎜⎢────────────────────────────────────────────────────────────────────────────
# ⎜⎢
# ⎜⎢
# ⎜⎢      3                 2         3                 2             2
# ⎜⎢cₜₕₑₜₐ ⋅c_{\theta \beta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 3.0⋅cₜₕₑₜₐ ⋅c_{\thet
# ⎜⎢
# ⎝⎣
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#         2                    2                        2
# a \beta} ⋅sₜₕₑₜₐ - 3.0⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + cₜₕₑₜₐ⋅c_{\theta \be
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2       2                          2                2                 2
# ta} ⋅sₜₕₑₜₐ  + cₜₕₑₜₐ⋅c_{\theta \beta}  + cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                       2                               ⎛
# ₜₕₑₜₐ⋅s_{\theta \beta}  - 2.0⋅cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                           ⎛                          2      ⎞⎞
# ⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                        2       3                   2
#  - 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + c_{\theta \beta} ⋅sₜₕₑₜₐ + 2.0⋅c_{\theta \b
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#      ⎛                        ⎛                          2      ⎞
# eta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_{\theta
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        ⎛       ⎛      2      ⎞          ⎛          2      ⎞⎞⎞             3
# \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠ - 3.0⋅sₜₕₑₜₐ ⋅s_
#
#
#
#                                                        ⎛
#                                                       -⎝2.0⋅cₜₕₑₜₐ⋅c_{\theta \
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                  ⎛
#               2                          2       ⎜                          2
# {\theta \beta}  + sₜₕₑₜₐ⋅s_{\theta \beta}  - 3.0⋅⎝- 0.444444444444444⋅cₜₕₑₜₐ ⋅
#
#
#
#       ⎛                                                                 ⎛
# beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎛      2                 4             2                 2                 2
# ⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + 2.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \beta}  +
#
#
#
#                      2      ⎞⎞                        ⎛
# ₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠ + 2.0⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2                 4                              4
#  cₜₕₑₜₐ ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 8.0⋅cₜₕₑₜₐ⋅
#
#                                           1.0
#
#  ⎛                          2      ⎞                    ⎛       ⎛      2
# ⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                 2                        2
# c_{\theta \beta} ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\theta \beta
#
#
#
# ⎞          ⎛          2      ⎞⎞⎞⎞
# ⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  4                       4       2                   4                       2
# }  + 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  - c_{\theta \beta}  + 6.0⋅c_{\theta \beta}
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2                 2                       2                 2
# ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - 2.0⋅c_{\theta \beta} ⋅s_{\theta \beta}  + 3.0⋅sₜₕ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2                 4                   4⎞   ⎛                        3
# ₑₜₐ ⋅s_{\theta \beta}  - s_{\theta \beta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            2                           3                 2         2
# heta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2                2                        2
#  \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                 2       2                                            2
# c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.333
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                           2                 2
# 333333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            2                   2       3                                     2
# heta \beta}  - c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \beta}
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                 3                 2
# ⋅sₜₕₑₜₐ - sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \beta
#
#
#
#
#
# ────────  ────────────────────────────────────────────────────────────────────
#      0.5
#    2⎞
#  2⎞ ⎟           3                 2         3                 2             2
# } ⎠ ⎠     cₜₕₑₜₐ ⋅c_{\theta \beta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 3.0⋅cₜₕₑₜₐ ⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                 2                    2                        2
# c_{\theta \beta} ⋅sₜₕₑₜₐ - 3.0⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + cₜₕₑₜₐ⋅c_{\t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            2       2                          2                2
# heta \beta} ⋅sₜₕₑₜₐ  + cₜₕₑₜₐ⋅c_{\theta \beta}  + cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \be
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2                          2                               ⎛
# ta}  + cₜₕₑₜₐ⋅s_{\theta \beta}  - 2.0⋅cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\thet
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                   ⎛                          2
# a \beta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       ⎞⎞                       2       3                   2
#  + 1.0⎠⎠ - 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + c_{\theta \beta} ⋅sₜₕₑₜₐ + 2.0⋅c_{\
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#              ⎛                        ⎛                          2      ⎞
# theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                ⎛       ⎛      2      ⎞          ⎛          2      ⎞⎞⎞
# {\theta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠ - 3.0⋅sₜ
#
#
#
#                                                                ⎛
#                                                               -⎝2.0⋅cₜₕₑₜₐ⋅c_{
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                          ⎛
#     3                 2                          2       ⎜
# ₕₑₜₐ ⋅s_{\theta \beta}  + sₜₕₑₜₐ⋅s_{\theta \beta}  + 3.0⋅⎝- 0.444444444444444⋅
#
#
#
#               ⎛
# \theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       2 ⎛      2                 4             2                 2
# cₜₕₑₜₐ ⋅⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + 2.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \
#
#
#
#   ⎛                          2      ⎞⎞                        ⎛
# }⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠ + 2.0⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\thet
# ──────────────────────────────────────────────────────────────────────────────
#
#
#      2         2                 4                              4
# beta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 8.0
#
#                                                   1.0
#
#          ⎛                          2      ⎞                    ⎛       ⎛
# a \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                         2                        2
# ⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\the
#
#
#
#  2      ⎞          ⎛          2      ⎞⎞⎞⎞
# ₐ  + 1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#          4                       4       2                   4
# ta \beta}  + 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  - c_{\theta \beta}  + 6.0⋅c_{\theta
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2       2                 2                       2                 2
#  \beta} ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - 2.0⋅c_{\theta \beta} ⋅s_{\theta \beta}  +
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            2                 4                   4⎞   ⎛
#  3.0⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - s_{\theta \beta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  3                 2                           3                 2         2
# ₐ ⋅c_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                2                2                        2
# _{\theta \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                         2       2                                            2
# ⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                   2                 2
#  + 0.333333333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                    2                   2       3
# ₜₐ⋅s_{\theta \beta}  - c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2                3                 2
#  \beta} ⋅sₜₕₑₜₐ - sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\the
#
#
#
#                 ⎤  ⎡                                     ⎛
#                 ⎥  ⎢                                     ⎜
# ────────────────⎥  ⎢                           0.5  -0.5 ⎜      3
#              0.5⎥  ⎢0.176776695296637⋅\sigmaₓ⋅a   ⋅r    ⋅⎝cₜₕₑₜₐ ⋅c_{\theta \b
#            2⎞   ⎥, ⎢
#          2⎞ ⎟   ⎥  ⎢
# ta \beta} ⎠ ⎠   ⎥  ⎢
#                 ⎥  ⎢
#                 ⎦  ⎣
#
#
#
#     2         3                 2             2                 2
# eta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 3.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 3.0
#
#
#
#
#
#
#
#
#        2                        2                          2       2
# ⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + cₜₕₑₜₐ⋅
#
#
#
#
#
#
#
#
#                 2                2                 2
# c_{\theta \beta}  + cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + cₜₕₑₜₐ⋅s_{\theta \beta}
#
#
#
#
#
#
#
#
# 2                       2       3                   2                    3
#   - 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + c_{\theta \beta} ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ ⋅s_{
#
#
#
#
#
#
#
#                                                 ⎛
#              2                          2       ⎜                          2 ⎛
# \theta \beta}  + sₜₕₑₜₐ⋅s_{\theta \beta}  - 3.0⋅⎝- 0.444444444444444⋅cₜₕₑₜₐ ⋅⎝
#
#
#
#
#
#
#
#
#       2                 4             2                 2                 2
# cₜₕₑₜₐ ⋅c_{\theta \beta}  + 2.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \beta}  +
#
#
#
#
#
#
#
#
#       2                 4                              4
# cₜₕₑₜₐ ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 8.0⋅cₜₕₑₜₐ⋅c
#
#
#
#
#
#
#
#
#                2                        2
# _{\theta \beta} ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\theta \beta}
#
#
#
#
#
#
#
#
# 4                       4       2                   4                       2
#   + 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  - c_{\theta \beta}  + 6.0⋅c_{\theta \beta} ⋅
#
#
#
#
#              0
#
#
#
#       2                 2                       2                 2
# sₜₕₑₜₐ ⋅s_{\theta \beta}  - 2.0⋅c_{\theta \beta} ⋅s_{\theta \beta}  + 3.0⋅sₜₕₑ
#
#
#
#
#
#
#
#
#   2                 4                   4⎞   ⎛                        3
# ₜₐ ⋅s_{\theta \beta}  - s_{\theta \beta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\th
#
#
#
#
#
#
#
#
#           2                           3                 2         2
# eta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta
#
#
#
#
#
#
#
#
#       2                2                        2
# \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅c
#
#
#
#
#
#
#
#
#                2       2                                            2
# _{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.3333
#
#
#
#
#
#
#
#
#                          2                 2
# 33333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\th
#
#
#
#
#
#
#
#
#           2                   2       3                                     2
# eta \beta}  - c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \beta} ⋅
#
#
#
#
#
#
#
#
#                3                 2
# sₜₕₑₜₐ - sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \beta}
#
#
#
#
#
#
#     0.5⎞
#   2⎞   ⎟
# 2⎞ ⎟   ⎟
#  ⎠ ⎠   ⎠
#
#                                                ⎛
#                                                ⎜
#                                      0.5  -0.5 ⎜      3                 2
#           0.176776695296637⋅\sigmaₓ⋅a   ⋅r    ⋅⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + cₜ
#
#
#
#
#
#
#
#
#     3                 2             2                 2                    2
# ₕₑₜₐ ⋅s_{\theta \beta}  - 3.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 3.0⋅cₜₕₑₜₐ ⋅s
#
#
#
#
#
#
#
#
#                       2                          2       2
# ₜₕₑₜₐ⋅s_{\theta \beta}  + cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + cₜₕₑₜₐ⋅c_{\theta
#
#
#
#
#
#
#
#
#       2                2                 2                          2
# \beta}  + cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + cₜₕₑₜₐ⋅s_{\theta \beta}  - 3.0⋅c_
#
#
#
#
#
#
#
#
#               2       3                   2                    3
# {\theta \beta} ⋅sₜₕₑₜₐ  + c_{\theta \beta} ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ ⋅s_{\theta \be
#
#
#
#
#
#
#
#                                       ⎛
#    2                          2       ⎜                          2 ⎛      2
# ta}  + sₜₕₑₜₐ⋅s_{\theta \beta}  + 3.0⋅⎝- 0.444444444444444⋅cₜₕₑₜₐ ⋅⎝cₜₕₑₜₐ ⋅c_
#
#
#
#
#
#
#
#
#               4             2                 2                 2         2
# {\theta \beta}  + 2.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \beta}  + cₜₕₑₜₐ ⋅s_
#
#
#
#
#
#
#
#
#               4                              4
# {\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 8.0⋅cₜₕₑₜₐ⋅c_{\theta \
#
#
#
#
#
#
#
#
#      2                        2                                     4
# beta} ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 3.0⋅c_
#
#
#
#
#    0
#
#
#
#               4       2                   4                       2       2
# {\theta \beta} ⋅sₜₕₑₜₐ  - c_{\theta \beta}  + 6.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ ⋅s_
#
#
#
#
#
#
#
#
#               2                       2                 2             2
# {\theta \beta}  - 2.0⋅c_{\theta \beta} ⋅s_{\theta \beta}  + 3.0⋅sₜₕₑₜₐ ⋅s_{\th
#
#
#
#
#
#
#
#
#           4                   4⎞   ⎛                        3
# eta \beta}  - s_{\theta \beta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\theta \beta}
#
#
#
#
#
#
#
#
# 2                           3                 2         2                 2
#   + 0.333333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅sₜ
#
#
#
#
#
#
#
#
#              2                        2
# ₕₑₜₐ - cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \
#
#
#
#
#
#
#
#
#      2       2                                            2
# beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.33333333333333
#
#
#
#
#
#
#
#
#                2                 2
# 3⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\theta \beta}
#
#
#
#
#
#
#
#
# 2                   2       3                                     2
#   - c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - s
#
#                                                                             ⎤⎞
#                                                                             ⎥⎟
#                                                                             ⎥⎟
#                                                                             ⎥⎟
#                                                                             ⎥⎟
#                                                                         0.5⎞⎥⎟
#                                                                       2⎞   ⎟⎥⎟
#      3                 2                                            2⎞ ⎟   ⎟⎥⎟
# ₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \beta} ⎠ ⎠   ⎠⎦⎠

# %%
sp.simplify(P_rt * D_rt * P_rt**(-1));

# %%
D = sp.expand_trig(D_rt)
D;

# %%
params = {a:15, r:3, c_t: 0.866, T:5, s_t:0.5} #theta: 0.52}

# %%
theta_ = sp.atan( sp.simplify(P_rt[0,0] / P_rt[1,0]))
theta_
# Out:
#      ⎛
#      ⎜
# -atan⎜────────────────────────────────────────────────────────────────────────
#      ⎜
#      ⎜
#      ⎜      3                 2         3                 2             2
#      ⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 3.0⋅cₜₕₑₜₐ ⋅c_{\
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             2                    2                        2
# theta \beta} ⋅sₜₕₑₜₐ - 3.0⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + cₜₕₑₜₐ⋅c_{\theta
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2       2                          2                2                 2
#  \beta} ⋅sₜₕₑₜₐ  + cₜₕₑₜₐ⋅c_{\theta \beta}  + cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                           2                               ⎛
#  + cₜₕₑₜₐ⋅s_{\theta \beta}  - 2.0⋅cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \b
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                               ⎛                          2
# eta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   ⎞⎞                       2       3                   2
# .0⎠⎠ - 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + c_{\theta \beta} ⋅sₜₕₑₜₐ + 2.0⋅c_{\thet
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#          ⎛                        ⎛                          2      ⎞
# a \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_{\th
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            ⎛       ⎛      2      ⎞          ⎛          2      ⎞⎞⎞
# eta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠ - 3.0⋅sₜₕₑₜₐ
#
#
#                                                             2.0⋅cₜₕₑₜₐ⋅c_{\the
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                      ⎛
# 3                 2                          2       ⎜
#  ⋅s_{\theta \beta}  + sₜₕₑₜₐ⋅s_{\theta \beta}  - 3.0⋅⎝- 0.444444444444444⋅cₜₕₑ
#
#           ⎛                                                                 ⎛
# ta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta}⋅⎝c
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   2 ⎛      2                 4             2                 2
# ₜₐ ⋅⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + 2.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \beta
#
#                          2      ⎞⎞                        ⎛
# ₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠ + 2.0⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  2         2                 4                              4
# }  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 8.0⋅cₜₕ
#
#      ⎛                          2      ⎞                    ⎛       ⎛      2
# eta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     2                        2
# ₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\theta \
#
#     ⎞          ⎛          2      ⎞⎞⎞
#  1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#      4                       4       2                   4
# beta}  + 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  - c_{\theta \beta}  + 6.0⋅c_{\theta \be
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2       2                 2                       2                 2
# ta} ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - 2.0⋅c_{\theta \beta} ⋅s_{\theta \beta}  + 3.0
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2                 4                   4⎞   ⎛                        3
# ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - s_{\theta \beta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                2                           3                 2         2
# _{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\t
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            2                2                        2
# heta \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕ
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     2       2                                            2
# ₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                               2                 2
# .333333333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                2                   2       3
# _{\theta \beta}  - c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \be
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2                3                 2
# ta} ⋅sₜₕₑₜₐ - sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \
#
#             ⎞
#             ⎟
# ────────────⎟
#          0.5⎟
#        2⎞   ⎟
#      2⎞ ⎟   ⎟
# beta} ⎠ ⎠   ⎠

# %%
d_theta_d_cs_thebe = theta_.diff(cs_thebe)
dcs_dthebe = cs_thebe_.diff(theta)
dtheta_theta = (d_theta_d_cs_thebe.T * dcs_dthebe)[0,0]
dtheta_theta
# Out:
#   ⎛
#   ⎜
#   ⎜                  ⎛                            ⎛
#   ⎜0.111111111111111⋅⎝2.0⋅cₜₕₑₜₐ⋅c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅(cₜ
#   ⎜───────────────────────────────────────────────────────────────────────────
#   ⎜
#   ⎜
#   ⎜
#   ⎜
#   ⎝
# - ────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                                       ⎛                          2      ⎞⎞
# ₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠ + 2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                     ⎛                        ⎛                          2
# .0⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#  ⎞                    ⎛       ⎛      2      ⎞          ⎛          2      ⎞⎞⎞⎞
# 0⎠ - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠⎠⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ⎛
# ⎜
# ⎜          3                              2
# ⎝- 2⋅cₜₕₑₜₐ ⋅s_{\theta \beta} + 6.0⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta} + 2.0⋅cₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#   2                                                                      ⎛
# ₜₐ ⋅s_{\theta \beta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - 2.0⋅cₜₕₑₜₐ⋅c_{\theta \beta}⋅⎝cₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                       2      ⎞                  2
# ₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - 2⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta} - 2⋅cₜₕₑₜₐ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#                                               ⎛
#                                               ⎜
#                                               ⎜                        3
#                                               ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                               ⎛
# s_{\theta \beta} + 2.0⋅cₜₕₑₜₐ⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2                           3                 2         2
# heta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                   ⎛                          2      ⎞⎞             3
#  c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠ + 6.0⋅sₜₕₑₜₐ ⋅s_{\theta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2                2                        2
#  \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                                           ⎛                          2 ⎛
#  \beta} - 2⋅sₜₕₑₜₐ⋅s_{\theta \beta} + 3.0⋅⎝- 0.222222222222222⋅cₜₕₑₜₐ ⋅⎝4.0⋅cₜ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2       2                                            2
# c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.333
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#     2                 2                            2                 3
# ₕₑₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \beta} + 4⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - 16.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                           2                 2
# 333333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                        2
# cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ⋅s_{\theta \beta} - 16.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\thet
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            2                                             ⎛
# heta \beta}  - 0.666666666666667⋅cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \be
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#         3                        2       2
# a \beta}  + 12.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ ⋅s_{\theta \beta} - 4.0⋅c_{\theta \b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                              ⎛                          2
# ta}⋅(cₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#     2                               2                 3                     3⎞
# eta} ⋅s_{\theta \beta} + 12.0⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - 4⋅s_{\theta \beta} ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  ⎞⎞                   2       3                                     2
# 0⎠⎠ - c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \beta} ⋅sₜₕₑₜₐ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#        ⎛                       3                            2
#  + 0.5⋅⎝1.33333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta} - 4⋅cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                     ⎛                        ⎛
#  0.666666666666667⋅c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                                         2
#  \beta} + 1.33333333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta \beta} + 1.33333333333333⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           2      ⎞                    ⎛       ⎛      2      ⎞          ⎛
# 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                                   3
# cₜₕₑₜₐ⋅s_{\theta \beta} - 4⋅sₜₕₑₜₐ ⋅s_{\theta \beta} + 1.33333333333333⋅sₜₕₑₜₐ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2      ⎞⎞⎞         3                 2
# ₕₑₜₐ  - 1.0⎠⎠⎠ - sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\thet
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                  ⎞ ⎛                        3                 2
# ⋅s_{\theta \beta}⎠⋅⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\theta \beta}  + 0.3333333333
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             ⎛
#         2   ⎜                          2 ⎛      2                 4
# a \beta}  - ⎝- 0.444444444444444⋅cₜₕₑₜₐ ⋅⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + 2.0⋅cₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                           ────────────────────────────────────────────────────
#
#                           ⎛
#                           ⎜
#                           ⎜                        3                 2
#                           ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\theta \beta}  + 0.333
#
#
#
#             3                 2         2                 2                2
# 33333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                 2                 2         2                 4
# ₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \beta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    3                 2         2                 2
# 333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - cₜ
#
#
#
#                       2                                            2       2
# ₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    4                                     2
# ₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 8.0⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ⋅s_{\theta \b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                        2                                            2
# ₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜ
#
#
#
#                                           2                                  2
#  0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                                     4                       4       2
# eta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                                            2
# ₕₑₜₐ  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅
#
#
#
#                  2                                            2
# ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\theta \beta}  - c_{\theta \b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 4                       2       2                 2
# c_{\theta \beta}  + 6.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - 2.0⋅c_{\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2                 2                                            2
# sₜₕₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\theta \beta}  - 0.666
#
#
#
#     2       3                                     2                3
# eta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - sₜₕₑₜₐ ⋅s_{\theta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             2                 2             2                 4
# theta \beta} ⋅s_{\theta \beta}  + 3.0⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - s_{\theta \b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                      ⎛
# 666666666667⋅cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅(cₜₕₑₜₐ - 3.0⋅sₜ
#
#
#                                                         ⎛
#        2                                            2⎞⎞ ⎜
#  \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \beta} ⎠⎠⋅⎝- 0.444444444444444⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     4⎞   ⎛                        3                 2
# eta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\theta \beta}  + 0.333333333333333⋅cₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                          ⎛                          2      ⎞⎞
# ₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠ - c_{\theta \bet
#
#
#
#      2 ⎛      2                 4             2                 2
# ₜₕₑₜₐ ⋅⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + 2.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅s_{\theta \b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   3                 2         2                 2                2
# ₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ ⋅sₜₕₑₜₐ⋅s_{\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2       3                                     2
# a} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \beta} ⋅sₜₕₑₜₐ + 0.666666666666667⋅c
#
#
#
#     2         2                 4                              4
# eta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - 8.0⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             2                                            2       2
# theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  + 0.3333333
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 ⎛                        ⎛                          2      ⎞
# _{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ -
#
#
#
#                        2                        2
# cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\thet
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                 2                                  2
# 33333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ ⋅s_{\theta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                          0.444
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                   ⎛       ⎛      2      ⎞          ⎛          2      ⎞⎞⎞
#  c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0⎠ - sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠⎠ - sₜₕ
#
#
#
#         4                       4       2                   4
# a \beta}  + 3.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ  - c_{\theta \beta}  + 6.0⋅c_{\theta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2                                            2                   2
#  \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\theta \beta}  - c_{\theta \beta} ⋅sₜₕₑ
# ──────────────────────────────────────────────────────────────────────────────
#
#              ⎛                        ⎛
# 444444444444⋅⎝cₜₕₑₜₐ⋅c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅(cₜₕₑₜₐ - 3.0⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                       ⎛
#    3                 2                                            2   ⎜
# ₑₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \beta}  - ⎝- 0.444
#
#
#
#       2       2                 2                       2                 2
# \beta} ⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - 2.0⋅c_{\theta \beta} ⋅s_{\theta \beta}  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   3                                     2                3                 2
# ₜₐ  + 0.333333333333333⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - sₜₕₑₜₐ ⋅s_{\theta \beta}  +
# ──────────────────────────────────────────────────────────────────────────────
#
#                           ⎛                          2      ⎞⎞
# ₜₕₑₜₐ) - c_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠⎠ + s_{\theta \be
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    2 ⎛      2                 4             2
# 444444444444⋅cₜₕₑₜₐ ⋅⎝cₜₕₑₜₐ ⋅c_{\theta \beta}  + 2.0⋅cₜₕₑₜₐ ⋅c_{\theta \beta}
#
#
#
#           2                 4                   4⎞   ⎛
# 3.0⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  - s_{\theta \beta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜₐ
# ──────────────────────────────────────────────────────────────────────────────
#                                                   2
#                                               0.5⎞
#                                             2⎞   ⎟
#                                           2⎞ ⎟   ⎟
#  0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \beta} ⎠ ⎠   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#     ⎛                        ⎛                          2      ⎞
# ta}⋅⎝cₜₕₑₜₐ⋅s_{\theta \beta}⋅⎝cₜₕₑₜₐ⋅sₜₕₑₜₐ - 3.0⋅sₜₕₑₜₐ  + 1.0⎠ - c_{\theta \
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                 2         2                 4                              4
#  ⋅s_{\theta \beta}  + cₜₕₑₜₐ ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅c_{\theta \beta}
#
#
#
# 3                 2                           3                 2         2
#  ⋅c_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ...
#
#                 ⎛         ⎛      2      ⎞          ⎛          2      ⎞⎞
# _{\theta \beta}⋅⎝- cₜₕₑₜₐ⋅⎝sₜₕₑₜₐ  + 1.0⎠ + sₜₕₑₜₐ⋅⎝3.0⋅sₜₕₑₜₐ  - 1.0⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  2                                     4
# ⋅s_{\theta \beta}  - 4.0⋅cₜₕₑₜₐ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 3.0⋅c_{\theta \beta
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  4       2                   4                       2       2
# } ⋅sₜₕₑₜₐ  - c_{\theta \beta}  + 6.0⋅c_{\theta \beta} ⋅sₜₕₑₜₐ ⋅s_{\theta \beta
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  2                       2                 2             2                 4
# }  - 2.0⋅c_{\theta \beta} ⋅s_{\theta \beta}  + 3.0⋅sₜₕₑₜₐ ⋅s_{\theta \beta}  -
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  4⎞   ⎛                        3                 2
#  s_{\theta \beta} ⎠ + ⎝0.333333333333333⋅cₜₕₑₜₐ ⋅c_{\theta \beta}  + 0.3333333
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                3                 2         2                 2
# 33333333⋅cₜₕₑₜₐ ⋅s_{\theta \beta}  - cₜₕₑₜₐ ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - cₜₕₑₜₐ
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 2                        2                                            2
#  ⋅sₜₕₑₜₐ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta} ⋅sₜₕₑₜₐ
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 2                                            2
#   + 0.333333333333333⋅cₜₕₑₜₐ⋅c_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅sₜₕₑ
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   2                 2                                            2
# ₜₐ ⋅s_{\theta \beta}  + 0.333333333333333⋅cₜₕₑₜₐ⋅s_{\theta \beta}  - c_{\theta
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        2       3                                     2                3
#  \beta} ⋅sₜₕₑₜₐ  + 0.333333333333333⋅c_{\theta \beta} ⋅sₜₕₑₜₐ - sₜₕₑₜₐ ⋅s_{\th
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                                                               ⎞
#                                                               ⎟
#                                                               ⎟
#                                                               ⎟
# ──────────────────────────────────────────────────────────────⎟⋅sin(\theta + 0
#                                                            0.5⎟
#                                                          2⎞   ⎟
#           2                                            2⎞ ⎟   ⎟
# eta \beta}  + 0.333333333333333⋅sₜₕₑₜₐ⋅s_{\theta \beta} ⎠ ⎠   ⎟
#                                                               ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .785398163397448)
#
#
#
#
#
# ─────────────────

# %%
get_theta_ = sp.lambdify((theta), theta_.subs(params))
theta_.subs(params)

# %%
f_ct_val = 3

# %%
_, (ax1) = plt.subplots(1, 1, figsize=(10,5))
sig_x = np.linspace(f_ct_val - 0.000001,-2*f_ct_val,100)
eta = 0.01
tau_xx = eta * f_ct_val
th_f = get_theta_f(
    tau_xx,sig_x[:, np.newaxis], f_ct_val)
th_0 = get_theta_0(
    tau_xx,sig_x[:, np.newaxis], f_ct_val)
ax1.plot(sig_x, th_f/np.pi * 180, color='blue', lw=2);
ax1.plot(sig_x, th_0/np.pi * 180, color='green', lw=2);
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
_, (ax1) = plt.subplots(1, 1, figsize=(10,5))
tau_val = np.linspace(0.00001, 0.1, 100)
th_f = get_theta_f(
    tau_val[np.newaxis, :],
    sig_x[:, np.newaxis], f_ct_val)
sig_z = get_sigma_z(
    tau_val[np.newaxis, :],
    sig_x[:, np.newaxis], f_ct_val)
ax1.plot(th_f, sig_z);
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
DELTA = np.ones(2)
P_x0_norm = P_x0.norm()
get_P_x0 = sp.lambdify((tau_fps, sigma_x, f_ct), P_x0, 'numpy')
get_P_xf = sp.lambdify((tau_fps, sigma_x, f_ct), P_xf, 'numpy')
get_D_x0 = sp.lambdify((tau_fps, sigma_x, f_ct), D_x0, 'numpy')
get_D_xf = sp.lambdify((tau_fps, sigma_x, f_ct), D_xf, 'numpy')

# %%
def get_D_x0_vals(tau_val = 1, sig_val = 2.8, f_ct = 3.0):
    D_x0_vals = get_D_x0(tau_val,sig_val, f_ct)
    D_x0_vct = np.einsum('...i,...ij->...j', DELTA, D_x0_vals)
    return D_x0_vct[np.newaxis,:]

# %%
def get_D_xf_vals(tau_val = 1, sig_val = 2.8, f_ct = 3):
    D_xf_vals = get_D_xf(tau_val,sig_val,f_ct)
    D_xf_vct = np.einsum('i,ij->j', DELTA, D_xf_vals)
    return D_xf_vct[np.newaxis,:]

# %%
def get_T_x0_args(tau_val, sig_val, f_ct): 
    P_x0_vals = get_P_x0(tau_val,sig_val,f_ct)
    print(P_x0_vals)
    norm_P_x0_vals2 = np.sqrt(np.einsum('ij,ij->j', P_x0_vals, P_x0_vals))
    T_x0 = P_x0_vals / norm_P_x0_vals2
    T_x0_scaled = T_x0 * get_D_x0_vals(tau_val, sig_val, f_ct)
    T_x0_0 = np.zeros_like(T_x0)
    T_x0_args = np.einsum('ijk->jik', np.array([T_x0_0, T_x0_scaled]))
    return T_x0_args

# %%
def get_T_xf_args(tau_val, sig_val, f_ct, pos = np.array([[0,0]])): 
    P_xf_vals = get_P_xf(tau_val,sig_val,f_ct)
    norm_P_xf_vals2 = np.sqrt(np.einsum('ij,ij->j', P_xf_vals, P_xf_vals))
    T_xf = P_xf_vals / norm_P_xf_vals2
    T_xf_scaled = T_xf * get_D_xf_vals(tau_val, sig_val, f_ct)
    T_xf_0 = np.zeros_like(T_xf)
    T_vxt = np.array([T_xf_0, T_xf_scaled])
    pos_lk = pos
    T_xf_args = pos_lk[:,None,:, None] + T_vxt[None,:,:,:]
    return np.einsum('lijk->jlik', T_xf_args)

# %%
tau_, sig_x_ = 1, 0.1
T_xf_args = get_T_xf_args(2,sig_x_,3, np.array([[1,0]]))
T_xf_args
# Out:
# array([[[[ 1.        ,  1.        ],
#          [ 2.05314463,  2.70319887]]],
#
#
#        [[[ 0.        ,  0.        ],
#          [-0.72630664,  2.46963836]]]])

# %%
sig_x_ = np.linspace(2.5, -2.5, 4)
sig_z_ = get_sigma_z(tau_,sig_x_, f_ct_val)
pos_lk = np.c_[sig_x_, sig_z_]
pos_lk
# Out:
# array([[ 2.5       ,  1.        ],
#        [ 0.83333333,  2.53846154],
#        [-0.83333333,  2.73913043],
#        [-2.5       ,  2.81818182]])

# %%
tau_, sig_x_ = 1, 0.1
T_x0_args = get_T_x0_args(tau_,sig_x_,3)
T_xf_args = get_T_xf_args(tau_,sig_x_,3, pos_lk)
fix, ax = plt.subplots(1,1)
ax.plot(*T_x0_args, color='blue');
ax.plot(*T_xf_args.reshape(2,-1,2), color='green');
ax.axis('equal');
# Out:
# [[-0.95124922  1.05124922]
#  [ 1.          1.        ]]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Global equilibrium

# %% [markdown]
# Derive the relation between the shear force and local moment at a point $x$ of a beam. Consider dead load $q_0$, vertical load at the right-hand-side of the beam and free rotation at the left end of the beam. $L$ represents the length of the shear zone section.

# %%
F, q_0, q, L_sz, M_q = sp.symbols('F, q_0, q, L_sz, M_q')
x_ = sp.symbols('x')

# %% [markdown]
# ## Single load $F$

# %% [markdown]
# Reaction in the support

# %%
R_F = F / 2

# %% [markdown]
# Bending moment at $x$

# %%
M_F = R_F * (L_sz - x_)
M_F

# %% [markdown]
# Shear force at $x$

# %%
Q_F = M_F.diff(x_)
Q_F

# %% [markdown]
# ## Uniform load $q$

# %% [markdown]
# Reaction

# %%
R_q = q * L_sz
R_q

# %% [markdown]
# Bending moment at $x$

# %%
M_x = R_q * (L_sz-x_) - q * (L_sz-x_) * (L_sz-x_) / 2
M_x

# %% [markdown]
# Check the boundary values

# %%
M_x.subs(x_,0), M_x.subs(x_, L_sz)

# %% [markdown]
# Shear force

# %%
Q_x = -sp.simplify(M_x.diff(x_))

# %% [markdown]
# Check the boundary values

# %%
Q_x.subs(x_,0), Q_x.subs(x_, L_sz)

# %%
sp.simplify(Q_x), sp.simplify(M_x)

# %%
get_M_x = sp.lambdify((x_, L_sz, q), M_x)
get_Q_x = sp.lambdify((x_, L_sz, q), Q_x)
x_arr = np.linspace(0,10,30)
M_x_arr = get_M_x(x_arr,10,1)
Q_x_arr = get_Q_x(x_arr,10,1)
ax = plt.axes()
ax.plot(x_arr, M_x_arr);
ax2 = ax.twinx()
ax2 = plt.plot(x_arr, Q_x_arr,color='green');

# %%
1 * 10 * 10 - 1 * 10 * 10 / 2

# %%
q_subs = sp.solve({M_q - M_x}, q)
q_subs

# %%
Q_q = Q_x.subs(q_subs)
sp.simplify(Q_q)

# %%
xxx_subs = {q_0:0, F:0}
q1_subs = sp.solve({M_q - M_x.subs(xxx_subs)}, q)
q1_subs

# %%
Q_q = Q_x.subs(xxx_subs).subs(q1_subs)
sp.simplify(Q_q)

# %%
sp.simplify(Q_q.subs(M_q, M_x.subs(xxx_subs)))

# %% [markdown]
# ## Combined uniform load and force

# %%
R_q, R_F

# %%
M_x

# %%
M_Fq_x = sp.simplify(M_F + M_x)
Q_Fq_x = sp.simplify(M_Fq_x.diff(x))
M_Fq_x, Q_Fq_x

# %%
get_M_x = sp.lambdify((x_, L_sz, q, F), M_Fq_x)
get_Q_x = sp.lambdify((x_, L_sz, q, F), Q_Fq_x)
x_arr = np.linspace(0,10,30)
M_x_arr = get_M_x(x_arr,10,1, 10)
Q_x_arr = get_Q_x(x_arr,10,1, 10)
ax = plt.axes()
ax.plot(x_arr, M_x_arr);
ax2 = ax.twinx()
ax2 = plt.plot(x_arr, Q_x_arr,color='green');

# %%
q_subs = sp.solve({M_q - M_Fq_x}, q)
q_subs

# %%
Q_q = Q_Fq_x.subs(q_subs)
sp.simplify(Q_q)

# %%
Q_q.subs(F,0)

# %%
F_subs = sp.solve({M_q - M_Fq_x}, F)
F_subs

# %%
Q_F = Q_Fq_x.subs(F_subs)
sp.simplify(Q_F)

# %%
Q_F.subs(q,0)

# %%
sp.simplify(Q_F.subs(M_q,M_Fq_x))

# %%
R_Fq = R_F + R_q
R_Fq

# %%
R_Fq.subs(q_subs)

# %%
sp.limit(R_Fq.subs(q_subs), x,L_sz)
