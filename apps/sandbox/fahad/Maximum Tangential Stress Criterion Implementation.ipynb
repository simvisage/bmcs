# %% [markdown]
# # Maximum Tangential Stress Criterion for Mixed Mode Failure

# %%
# %matplotlib notebook
import sympy as sp
import numpy as np
sp.init_printing()
import matplotlib.pyplot as plt
import ipywidgets as ipw

# %%
r = sp.Symbol('r', nonnegative = True)
theta = sp.Symbol(r'\theta', nonnegative = True)
K_I = sp.Symbol('K_I', nonnegative = True)
K_II = sp.Symbol('K_{II}', nonnegative = True)
T = sp.Symbol('T', nonnegative = True)
sigma_x =  sp.Symbol(r'\sigma_x', nonnegative = True)
sigma_z =  sp.Symbol(r'\sigma_z', nonnegative = True)
tau_fps = sp.Symbol(r'\tau_\mathrm{fps}')
a = sp.Symbol('a', nonnegative = True)
beta = sp.Symbol(r'\beta', nonnegative = True)
tau_fps
# Out:
# \tau_\mathrm{fps}

# %% [markdown]
# ## Representation of Global Stresses
# The stresses in the global co-ordinates are expressed as:
# \begin{align}
# \sigma_{xz} =
# \left[
# \begin{array}{cc}
# \sigma_{xx} & \tau_{xz} \\
# \tau_{zx} & \sigma_{zz}
# \end{array}
# \right] =
# \left[
# \begin{array}{cc}
# \sigma_{x} & \tau^\mathrm{fps} \\
# \tau^\mathrm{fps} & \sigma_{z}
# \end{array}
# \right]
# \end{align}

# %% [markdown]
# In our case $\sigma_z = 0$ as the specimen is uniaxially loaded therefore, the stress will be depicted as follows:
# The stresses in the global co-ordinates are expressed as:
# \begin{align}
# \sigma_{xz} =
# \left[
# \begin{array}{cc}
# \sigma_{xx} & \tau_{xz} \\
# \tau_{zx} & 0
# \end{array}
# \right] =
# \left[
# \begin{array}{cc}
# \sigma_{x} & \tau^\mathrm{fps} \\
# \tau^\mathrm{fps} & 0
# \end{array}
# \right]
# \end{align}
# $\sigma_x, \tau_{fps}, \sigma_z$ represents the stress in x-direction, shear stress in fracture process segment and stress in vertical direction respectively.

# %% [markdown]
# <img src="farfieldstress.png" width="500"/>

# %%
sigma_xz = sp.Matrix([[sigma_x, tau_fps],
                     [tau_fps, sigma_z]])
sigma_x0 = sigma_xz.subs(sigma_z,0)
sigma_xz, sigma_x0
# Out:
# ⎛⎡     \sigmaₓ       \tau_\mathrm{fps}⎤  ⎡     \sigmaₓ       \tau_\mathrm{fps}
# ⎜⎢                                    ⎥, ⎢
# ⎝⎣\tau_\mathrm{fps}      \sigma_z     ⎦  ⎣\tau_\mathrm{fps}          0
#
# ⎤⎞
# ⎥⎟
# ⎦⎠

# %%
P_xz, D_xz = sigma_xz.diagonalize()
P_x0, D_x0 = P_xz.subs(sigma_z,0), D_xz.subs(sigma_z,0)
P_xz, D_xz
# Out:
# ⎛
# ⎜
# ⎜⎡                                  -2⋅\tau_\mathrm{fps}
# ⎜⎢────────────────────────────────────────────────────────────────────────────
# ⎜⎢                        ____________________________________________________
# ⎜⎢                       ╱        2                                2
# ⎜⎢\sigmaₓ - \sigma_z + ╲╱  \sigmaₓ  - 2⋅\sigmaₓ⋅\sigma_z + \sigma_z  + 4⋅\tau_
# ⎜⎢
# ⎜⎣                                            1
# ⎜
# ⎝
#
#
#
#                                                     2⋅\tau_\mathrm{fps}
# ──────────────  ──────────────────────────────────────────────────────────────
# ______________                           _____________________________________
#             2                           ╱        2
# \mathrm{fps}    -\sigmaₓ + \sigma_z + ╲╱  \sigmaₓ  - 2⋅\sigmaₓ⋅\sigma_z + \sig
#
#                                                              1
#
#
#
#                                 ⎡                        _____________________
#                                 ⎢                       ╱        2
#                              ⎤  ⎢\sigmaₓ   \sigma_z   ╲╱  \sigmaₓ  - 2⋅\sigmaₓ
# ─────────────────────────────⎥  ⎢─────── + ──────── - ────────────────────────
# _____________________________⎥  ⎢   2         2
#     2                      2 ⎥, ⎢
# ma_z  + 4⋅\tau_\mathrm{fps}  ⎥  ⎢
#                              ⎥  ⎢
#                              ⎦  ⎢
#                                 ⎢                                            0
#                                 ⎣
#
# _____________________________________________
#                     2                      2
# ⋅\sigma_z + \sigma_z  + 4⋅\tau_\mathrm{fps}
# ─────────────────────────────────────────────
#           2
#
#                                                                        _______
#                                                                       ╱
#                                                \sigmaₓ   \sigma_z   ╲╱  \sigma
#                                                ─────── + ──────── + ──────────
#                                                   2         2
#
#                                                            ⎤⎞
#                                                            ⎥⎟
#                                                            ⎥⎟
#              0                                             ⎥⎟
#                                                            ⎥⎟
#                                                            ⎥⎟
# ___________________________________________________________⎥⎟
#  2                                2                      2 ⎥⎟
# ₓ  - 2⋅\sigmaₓ⋅\sigma_z + \sigma_z  + 4⋅\tau_\mathrm{fps}  ⎥⎟
# ───────────────────────────────────────────────────────────⎥⎟
#                         2                                  ⎦⎠

# %%
P_x0, D_x0
# Out:
# ⎛
# ⎜
# ⎜⎡            -2⋅\tau_\mathrm{fps}                              2⋅\tau_\mathrm
# ⎜⎢──────────────────────────────────────────────  ────────────────────────────
# ⎜⎢             _________________________________                ______________
# ⎜⎢            ╱        2                      2                ╱        2
# ⎜⎢\sigmaₓ + ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}    -\sigmaₓ + ╲╱  \sigmaₓ  + 4⋅
# ⎜⎢
# ⎜⎣                      1                                                1
# ⎜
# ⎝
#
#                       ⎡             _________________________________
#                       ⎢            ╱        2                      2
# {fps}              ⎤  ⎢\sigmaₓ   ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}
# ───────────────────⎥  ⎢─────── - ────────────────────────────────────
# ___________________⎥  ⎢   2                       2
#                  2 ⎥, ⎢
# \tau_\mathrm{fps}  ⎥  ⎢
#                    ⎥  ⎢
#                    ⎦  ⎢                                                \sigmaₓ
#                       ⎢                      0                         ───────
#                       ⎣                                                   2
#
#                                        ⎤⎞
#                                        ⎥⎟
#                                        ⎥⎟
#                0                       ⎥⎟
#                                        ⎥⎟
#                                        ⎥⎟
#       _________________________________⎥⎟
#      ╱        2                      2 ⎥⎟
#    ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}  ⎥⎟
#  + ────────────────────────────────────⎥⎟
#                     2                  ⎦⎠

# %%
sp.simplify(P_xz* D_xz * P_xz**(-1))
# Out:
# ⎡     \sigmaₓ       \tau_\mathrm{fps}⎤
# ⎢                                    ⎥
# ⎣\tau_\mathrm{fps}      \sigma_z     ⎦

# %%
sp.simplify(P_x0* D_x0 * P_x0**(-1))
# Out:
# ⎡     \sigmaₓ       \tau_\mathrm{fps}⎤
# ⎢                                    ⎥
# ⎣\tau_\mathrm{fps}          0        ⎦

# %% [markdown]
# ## Representation of Far field stress in terms of Stress Intensity factors
# In this implementation, the far field stresses are represented in  terms of Stress Intensity factors (SIFs) where $K_I$ represents mode I failure and $K_{II}$ depicts mode II failure. This terminology of measuring stresses in SIFs for external stress acting in uniaxial direction is shown as:
# \begin{gather*}
# K_I = \sigma_x \sqrt{\pi a}\sin^2 \beta  \\
# K_{II} = \sigma_x \sqrt{\pi a}\sin\beta \cos\beta
# \end{gather*}
# The positive sign of $K_I$ highlights stress as tension where negative sign shows compression. Similarly, negative sign of $K_{II}$ represents stress in opposite direction. $\beta$ represents the angle of crack orientation with respect to the vertical direction and $a$ represents the length of crack as depicted in figure. In the case of pure mode I failure, $\beta$ is $90°$ whereas for failure along pure mode II $\beta = 0°$.

# %% [markdown]
# <img src="crack.png" width="600"/>

# %% [markdown]
# The figure shows stresses in the vicinity of crack tip. $\theta$ depicts crack propagation angle and $r$ represents the radius of fracture propagation segment.

# %%
K_I = sigma_x * sp.sqrt(sp.pi * a) * sp.sin(beta)**2
K_II  = sigma_x * sp.sqrt(sp.pi * a) * sp.cos(beta) * sp.sin(beta)
K_I, K_II
# Out:
# ⎛                 2                                            ⎞
# ⎝√π⋅\sigmaₓ⋅√a⋅sin (\beta), √π⋅\sigmaₓ⋅√a⋅sin(\beta)⋅cos(\beta)⎠

# %%
params = {beta:90*np.pi/180}

# %%
K_I_ = K_I.subs(params)
K_II_ = 0 #K_II.subs(params)
K_I_, K_II_
# Out:
# (1.0⋅√π⋅\sigmaₓ⋅√a, 0)

# %% [markdown]
# ## Maximum Stress Theory
# This theory was given by Sih and Erdogan. It is based on the two dimensional stresses acting on the vicinity of the crack. These stresses are given in the figure below. Moreover, they are represented as:
# \begin{align}
# \label{eq:sigrr}
# \sigma_{rr} &= \frac{1}{\sqrt{2 \pi r}}\left( K_I \left( \cos \frac{\theta}{2}\left(1 + \sin^2 \frac{\theta}{2}\right)\right) + K_{II}\left(\sin \frac{\theta}{2}\left(1 -
# 3 \sin^2 \frac{\theta}{2} \right) \right) \right) + T \cos^2 \theta
# \end{align}
# \begin{align}
# \label{eq:sigtt}
# \sigma_{\theta\theta}
# & = \frac{1}{\sqrt{2 \pi r}}\left( K_I \left( \cos^3 \frac{\theta}{2} \right) - K_{II}\left(3 \sin \frac{\theta}{2} \cos^2 \frac{\theta}{2} \right) \right) + T \sin^2 \theta
# \end{align}
# \begin{align}
# \label{eq:sigtr}
# \sigma_{r\theta}
# & = \frac{1}{\sqrt{2 \pi r}}\left( K_I \left(\sin \frac{\theta}{2} \cos^2 \frac{\theta}{2} \right) + K_{II}\left(\cos \frac{\theta}{2}\left(1 - 3 \sin^2 \frac{\theta}{2} \right) \right) \right) + T \sin \theta \cos \theta
# \end{align}
# For simplicity T-Stress is neglected.

# %%
## Representation of sin and cos components as s_t and c_t for simplicity.
s_t, c_t = sp.symbols('s_t,c_t')

# %%
sigma_rr = 1/sp.sqrt(2 * sp.pi *r) * (K_I_*c_t*(1 + (s_t)**2) \
                                      + (K_II_*s_t)*(1 - 3*(s_t)**2)) #+ T*(sp.cos(theta))**2
sigma_rr
# Out:
#                      ⎛  2    ⎞
# 0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ⋅⎝sₜ  + 1⎠
# ──────────────────────────────
#               √r

# %%
sigma_tt = 1/sp.sqrt(2 * sp.pi *r) * (K_I_*(c_t)**3 \
                                      - (K_II_*(3*s_t*(c_t)**2))) #+ T*sp.sin(theta)**2
sigma_tt
# Out:
#                     3
# 0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ
# ─────────────────────
#           √r

# %%
sigma_rt = 1/sp.sqrt(2 * sp.pi *r) * ((K_I_*(s_t*(c_t)**2)) \
                                      + ((K_II_*c_t)*(1 - 3*(s_t)**2))) # T*sp.sin(theta)*sp.cos(theta)
sigma_rt
# Out:
#                     2
# 0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ ⋅sₜ
# ────────────────────────
#            √r

# %% [markdown]
# The stresses in the vicinity of the crack will be represented by tensorial representation as:
# The stresses in the global co-ordinates are expressed as:
# \begin{align}
# \sigma_{xz} =
# \left[
# \begin{array}{cc}
# \sigma_{rr} & \tau_{rt} \\
# \tau_{rt} & \sigma_{tt}
# \end{array}
# \right]
# \end{align}

# %%
sigma = sp.Matrix([[sigma_rr, sigma_rt],
                     [sigma_rt, sigma_tt]])
sigma
# Out:
# ⎡                     ⎛  2    ⎞                      2   ⎤
# ⎢0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ⋅⎝sₜ  + 1⎠  0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ ⋅sₜ⎥
# ⎢──────────────────────────────  ────────────────────────⎥
# ⎢              √r                           √r           ⎥
# ⎢                                                        ⎥
# ⎢                       2                             3  ⎥
# ⎢   0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ ⋅sₜ      0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ   ⎥
# ⎢   ────────────────────────      ─────────────────────  ⎥
# ⎣              √r                           √r           ⎦

# %% [markdown]
# For verification and simplicity, $\sigma_{rr} = 0$.

# %%
sigma_0 = sigma.subs(sigma_rr,0)
sigma_0
# Out:
# ⎡                                              2   ⎤
# ⎢                          0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ ⋅sₜ⎥
# ⎢           0              ────────────────────────⎥
# ⎢                                     √r           ⎥
# ⎢                                                  ⎥
# ⎢                    2                          3  ⎥
# ⎢0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ ⋅sₜ   0.5⋅√2⋅\sigmaₓ⋅√a⋅cₜ   ⎥
# ⎢────────────────────────   ─────────────────────  ⎥
# ⎣           √r                        √r           ⎦

# %%
P_rt, D_rt = sigma_0.diagonalize()
P_0t, D_0t = P_rt.subs(sigma_rr,0), D_rt.subs(sigma_rr,0)
P_rt, D_rt
# Out:
# ⎛⎡           2.0⋅sₜ                        2.0⋅sₜ           ⎤  ⎡
# ⎜⎢────────────────────────────  ────────────────────────────⎥  ⎢
# ⎜⎢                         0.5                           0.5⎥  ⎢0.353553390593
# ⎜⎢         ⎛       2     2⎞              ⎛       2     2⎞   ⎥, ⎢
# ⎜⎢cₜ - 2.0⋅⎝0.25⋅cₜ  + sₜ ⎠     cₜ + 2.0⋅⎝0.25⋅cₜ  + sₜ ⎠   ⎥  ⎢
# ⎜⎢                                                          ⎥  ⎢
# ⎝⎣            1.0                           1.0             ⎦  ⎣
#
#                            ⎛                         0.5⎞
#              0.5   2  -0.5 ⎜         ⎛       2     2⎞   ⎟
# 274⋅\sigmaₓ⋅a   ⋅cₜ ⋅r    ⋅⎝cₜ - 2.0⋅⎝0.25⋅cₜ  + sₜ ⎠   ⎠
#
#
#
#                      0                                     0.353553390593274⋅\
#
#                                                     ⎤⎞
#                                                     ⎥⎟
#                 0                                   ⎥⎟
#                                                     ⎥⎟
#                       ⎛                         0.5⎞⎥⎟
#         0.5   2  -0.5 ⎜         ⎛       2     2⎞   ⎟⎥⎟
# sigmaₓ⋅a   ⋅cₜ ⋅r    ⋅⎝cₜ + 2.0⋅⎝0.25⋅cₜ  + sₜ ⎠   ⎠⎦⎠

# %%
sp.simplify(P_rt * D_rt * P_rt**(-1))
# Out:
# ⎡
# ⎢                                             0
# ⎢
# ⎢                           ⎛
# ⎢             0.5   2  -0.5 ⎜                      2                     ⎛
# ⎢1.0⋅\sigmaₓ⋅a   ⋅cₜ ⋅r    ⋅⎝- 0.176776695296637⋅cₜ  + 0.707106781186548⋅⎝0.25
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎣                                             sₜ
#
#                                             0.5   2  -0.5   ⎤
#                  0.707106781186548⋅\sigmaₓ⋅a   ⋅cₜ ⋅r    ⋅sₜ⎥
#                                                             ⎥
#            1.0⎞                                             ⎥
#    2     2⎞   ⎟                                             ⎥
# ⋅cₜ  + sₜ ⎠   ⎠                              0.5   3  -0.5  ⎥
# ───────────────   0.707106781186548⋅\sigmaₓ⋅a   ⋅cₜ ⋅r      ⎥
#                                                             ⎦

# %%
subs_sigma_z = sp.solve({D_xz[1,1] - sigma_tt}, {sigma_z})[0]
subs_sigma_z
# Out:
# ⎧                                   2      3             2     6
# ⎪          - 1.4142135623731⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\m
# ⎨\sigma_z: ───────────────────────────────────────────────────────────────────
# ⎪                                  ⎛                 0.5   3  0.5        ⎞
# ⎩                          \sigmaₓ⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#
#           2  ⎫
# athrm{fps} ⋅r⎪
# ─────────────⎬
#              ⎪
#              ⎭

# %%
sp.limit( sigma_z.subs(subs_sigma_z), sigma_x, sigma_tt)
# Out:
#       ⎛        3/2   9                            6  3/2           1.5   9  1.
#       ⎜1.0⋅√2⋅a   ⋅cₜ ⋅r - 1.4142135623731⋅√2⋅a⋅cₜ ⋅r    + 1.0⋅√2⋅a   ⋅cₜ ⋅r
# ∞⋅sign⎜───────────────────────────────────────────────────────────────────────
#       ⎜                                          0.5   3  2.0        1.0   6
#       ⎝                        5.65685424949238⋅a   ⋅cₜ ⋅r    - 2.0⋅a   ⋅cₜ ⋅r
#
# 0                         2.0   12  0.5⎞
#   - 0.707106781186548⋅√2⋅a   ⋅cₜ  ⋅r   ⎟
# ───────────────────────────────────────⎟
# 1.5        5/2                         ⎟
#     - 4.0⋅r                            ⎠

# %%
sigma_xf = sigma_xz.subs(subs_sigma_z)
sigma_xf
# Out:
# ⎡     \sigmaₓ                                      \tau_\mathrm{fps}
# ⎢
# ⎢                                            2      3             2     6
# ⎢                   - 1.4142135623731⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.
# ⎢\tau_\mathrm{fps}  ──────────────────────────────────────────────────────────
# ⎢                                           ⎛                 0.5   3  0.5
# ⎣                                   \sigmaₓ⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2
#
#                       ⎤
#                       ⎥
#                    2  ⎥
# 0⋅\tau_\mathrm{fps} ⋅r⎥
# ──────────────────────⎥
#     ⎞                 ⎥
# .0⋅r⎠                 ⎦

# %%
P_xf = P_xz.subs(subs_sigma_z)
D_xf = D_xz.subs(subs_sigma_z)
P_xf
# Out:
# ⎡
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                    _________________________________________________________
# ⎢                   ╱
# ⎢                  ╱         2
# ⎢                 ╱   \sigmaₓ                     2   - 1.4142135623731⋅\sigma
# ⎢\sigmaₓ + 2⋅    ╱    ──────── + \tau_\mathrm{fps}  - ────────────────────────
# ⎢               ╱        4                                                 ⎛
# ⎢              ╱                                                         2⋅⎝1.
# ⎢            ╲╱
# ⎢
# ⎣
#
#                                                                    -2⋅\tau_\ma
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#  2      3             2     6                        2          ⎛
# ₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r   0.25⋅⎝- 0.707106781
# ──────────────────────────────────────────────────────── + ───────────────────
#                0.5   3  0.5        ⎞
# 4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#
#
#                                                                              1
#
# thrm{fps}
# ──────────────────────────────────────────────────────────────────────────────
# ________________________________________________________________________
#                                                                       2
#               2      3                 2     6                    2  ⎞
# 186548⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + 0.5⋅\sigmaₓ ⋅a⋅cₜ  - \tau_\mathrm{fps} ⋅r⎠     - 1
# ───────────────────────────────────────────────────────────────────────  - ───
#                                                 2
#          2 ⎛                   0.5   3  0.5    ⎞
#   \sigmaₓ ⋅⎝0.707106781186548⋅a   ⋅cₜ ⋅r    - r⎠
#
#
#
#
# ─────────────────────────────────────────────────────────────────────────────
#
#
#                       2      3             2     6                        2
# .4142135623731⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r
# ─────────────────────────────────────────────────────────────────────────────
#                      ⎛                 0.5   3  0.5        ⎞
#              \sigmaₓ⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#
#
#
#
#
#  ─────────────────────────────────────────────────────────────────────────────
#                       ________________________________________________________
#                      ╱
#                     ╱         2
#                    ╱   \sigmaₓ                     2   - 1.4142135623731⋅\sigm
#  -\sigmaₓ + 2⋅    ╱    ──────── + \tau_\mathrm{fps}  - ───────────────────────
#                  ╱        4                                                 ⎛
#                 ╱                                                         2⋅⎝1
#               ╲╱
#
#
#
#                                                                      2⋅\tau_\m
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#   2      3             2     6                        2          ⎛
# aₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r   0.25⋅⎝- 0.70710678
# ───────────────────────────────────────────────────────── + ──────────────────
#                 0.5   3  0.5        ⎞
# .4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#
#
#
#
# athrm{fps}
# ──────────────────────────────────────────────────────────────────────────────
# _________________________________________________________________________
#                                                                        2
#                2      3                 2     6                    2  ⎞
# 1186548⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + 0.5⋅\sigmaₓ ⋅a⋅cₜ  - \tau_\mathrm{fps} ⋅r⎠     -
# ────────────────────────────────────────────────────────────────────────  + ──
#                                                  2
#           2 ⎛                   0.5   3  0.5    ⎞
#    \sigmaₓ ⋅⎝0.707106781186548⋅a   ⋅cₜ ⋅r    - r⎠
#
# 1
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                        2      3             2     6                        2
# 1.4142135623731⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r
# ──────────────────────────────────────────────────────────────────────────────
#                       ⎛                 0.5   3  0.5        ⎞
#               \sigmaₓ⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#
#
#
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦

# %%
D_xf
# Out:
# ⎡                  ___________________________________________________________
# ⎢                 ╱
# ⎢                ╱         2                                                 2
# ⎢\sigmaₓ        ╱   \sigmaₓ                     2   - 1.4142135623731⋅\sigmaₓ
# ⎢─────── -     ╱    ──────── + \tau_\mathrm{fps}  - ──────────────────────────
# ⎢   2         ╱        4                                                 ⎛
# ⎢            ╱                                                         2⋅⎝1.41
# ⎢          ╲╱
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
# ______________________________________________________________________________
#
#       3             2     6                        2          ⎛
# ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r   0.25⋅⎝- 0.70710678118
# ────────────────────────────────────────────────────── + ─────────────────────
#              0.5   3  0.5        ⎞
# 42135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#
#
#
#
#
#
#                                                                             0
#
#
#
#
# ______________________________________________________________________
#                                                                     2
#             2      3                 2     6                    2  ⎞
# 6548⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + 0.5⋅\sigmaₓ ⋅a⋅cₜ  - \tau_\mathrm{fps} ⋅r⎠     - 1.4
# ─────────────────────────────────────────────────────────────────────  + ─────
#                                               2
#        2 ⎛                   0.5   3  0.5    ⎞
# \sigmaₓ ⋅⎝0.707106781186548⋅a   ⋅cₜ ⋅r    - r⎠
#
#
#
#
#
#
#
#
#
#
#
#
#                     2      3             2     6                        2
# 142135623731⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r
# ───────────────────────────────────────────────────────────────────────────
#                     ⎛                 0.5   3  0.5        ⎞
#           2⋅\sigmaₓ⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#
#
#
#
#
#                                                                              \
#                                                                              ─
#
#
#
#
#
#
#
#
#
#
#
#
#
#                  _____________________________________________________________
#                 ╱
#                ╱         2                                                 2
# sigmaₓ        ╱   \sigmaₓ                     2   - 1.4142135623731⋅\sigmaₓ ⋅√
# ────── +     ╱    ──────── + \tau_\mathrm{fps}  - ────────────────────────────
#   2         ╱        4                                                 ⎛
#            ╱                                                         2⋅⎝1.4142
#          ╲╱
#
#
#
#
#
#                                                                           0
#
#
#
#
# ______________________________________________________________________________
#
#     3             2     6                        2          ⎛
# a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r   0.25⋅⎝- 0.7071067811865
# ──────────────────────────────────────────────────── + ───────────────────────
#            0.5   3  0.5        ⎞
# 135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
#                                                                             \s
#
#
#
#
#
#
#
#
#
#
# ____________________________________________________________________
#                                                                   2
#           2      3                 2     6                    2  ⎞
# 48⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + 0.5⋅\sigmaₓ ⋅a⋅cₜ  - \tau_\mathrm{fps} ⋅r⎠     - 1.414
# ───────────────────────────────────────────────────────────────────  + ───────
#                                             2
#      2 ⎛                   0.5   3  0.5    ⎞
# igmaₓ ⋅⎝0.707106781186548⋅a   ⋅cₜ ⋅r    - r⎠
#
#                                                                          ⎤
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                                                                          ⎥
#                   2      3             2     6                        2  ⎥
# 2135623731⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r + \sigmaₓ ⋅a⋅cₜ  - 2.0⋅\tau_\mathrm{fps} ⋅r⎥
# ─────────────────────────────────────────────────────────────────────────⎥
#                   ⎛                 0.5   3  0.5        ⎞                ⎥
#         2⋅\sigmaₓ⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠                ⎥
#                                                                          ⎦

# %%
params = {a:2, r:2, c_t: 0.866}

# %%
theta_f = sp.atan( sp.simplify(-P_xf[0,0] / P_xf[1,0]))
theta_0 = sp.atan( sp.simplify(-P_x0[0,0] / P_x0[1,0]))
theta_f
# Out:
#     ⎛
#     ⎜
# atan⎜─────────────────────────────────────────────────────────────────────────
#     ⎜                                                              ⎛
#     ⎜                                                              ⎜
#     ⎜                                                              ⎜
#     ⎜                       2      3             2     6           ⎜
#     ⎜1.4142135623731⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r - \sigmaₓ ⋅a⋅cₜ  + \sigmaₓ⋅⎜\sigmaₓ +
#     ⎜                                                              ⎜
#     ⎜                                                              ⎜
#     ⎝                                                              ⎝
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         ______________________________________________________________________
#        ╱
#       ╱         2 ⎛       2                      2⎞ ⎛                   0.5
#      ╱   \sigmaₓ ⋅⎝\sigmaₓ  + 4⋅\tau_\mathrm{fps} ⎠⋅⎝0.707106781186548⋅a   ⋅cₜ
#     ╱    ─────────────────────────────────────────────────────────────────────
#    ╱
#   ╱
# ╲╱
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#            2
# 3  0.5    ⎞  ⎛                  0.5   3  0.5        ⎞          2 ⎛
#  ⋅r    - r⎠ ⋅⎝2.82842712474619⋅a   ⋅cₜ ⋅r    - 4.0⋅r⎠ + \sigmaₓ ⋅⎝0.7071067811
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                 ⎛                 0.5   3  0.5        ⎞
#     2⋅\sigmaₓ⋅\tau_\mathrm{fps}⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                         2
#        0.5   3  0.5    ⎞  ⎛                        2      3               2
# 86548⋅a   ⋅cₜ ⋅r    - r⎠ ⋅⎝5.65685424949238⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r - 4⋅\sigmaₓ ⋅a⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
#         2 ⎛                   0.5   3  0.5    ⎞  ⎛                  0.5   3  0
#  \sigmaₓ ⋅⎝0.707106781186548⋅a   ⋅cₜ ⋅r    - r⎠ ⋅⎝2.82842712474619⋅a   ⋅cₜ ⋅r
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#   6                        2  ⎞   ⎛                  0.5   3  0.5        ⎞ ⎛
# cₜ  + 8.0⋅\tau_\mathrm{fps} ⋅r⎠ + ⎝2.82842712474619⋅a   ⋅cₜ ⋅r    - 4.0⋅r⎠⋅⎝0.
# ──────────────────────────────────────────────────────────────────────────────
#
# .5        ⎞
#    - 4.0⋅r⎠
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#                        2      3                 2     6                    2
# 707106781186548⋅\sigmaₓ ⋅√a⋅cₜ ⋅√r - 0.5⋅\sigmaₓ ⋅a⋅cₜ  + \tau_\mathrm{fps} ⋅r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                        ⎞
#                                                                        ⎟
# ───────────────────────────────────────────────────────────────────────⎟
# ___⎞                                                                   ⎟
#  2 ⎟                                                                   ⎟
# ⎞  ⎟                                                                   ⎟
# ⎠  ⎟ ⎛                 0.5   3  0.5        ⎞                        2  ⎟
# ── ⎟⋅⎝1.4142135623731⋅a   ⋅cₜ ⋅r    - 2.0⋅r⎠ + 2.0⋅\tau_\mathrm{fps} ⋅r⎟
#    ⎟                                                                   ⎟
#    ⎟                                                                   ⎟
#    ⎠                                                                   ⎠

# %%
theta_0
# Out:
#     ⎛             2⋅\tau_\mathrm{fps}              ⎞
# atan⎜──────────────────────────────────────────────⎟
#     ⎜             _________________________________⎟
#     ⎜            ╱        2                      2 ⎟
#     ⎝\sigmaₓ + ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}  ⎠

# %%
get_theta_f = sp.lambdify((tau_fps, sigma_x), theta_f.subs(params))
get_theta_0 = sp.lambdify((tau_fps, sigma_x), theta_0.subs(params))
theta_f.subs(params)
# Out:
#      ⎛
# -atan⎜────────────────────────────────────────────────────────────────────────
#      ⎜                                                      ⎛
#      ⎜                                                      ⎜
#      ⎜                                                      ⎜
#      ⎜                         2                            ⎜
#      ⎜0.993354134423659⋅\sigmaₓ  - 2.16304435686451⋅\sigmaₓ⋅⎜\sigmaₓ + 0.44454
#      ⎜                                                      ⎜
#      ⎝                                                      ⎝
#
#                                                                            4.3
# ──────────────────────────────────────────────────────────────────────────────
#                   ____________________________________________________________
#                  ╱  ⎛
#                 ╱   ⎜                          2 ⎛       2
#                ╱   -⎝- 5.06018366986055⋅\sigmaₓ ⋅⎝\sigmaₓ  + 4⋅\tau_\mathrm{fp
# 6156392408⋅   ╱    ───────────────────────────────────────────────────────────
#              ╱
#            ╲╱
#
# 2608871372902⋅\sigmaₓ⋅\tau_\mathrm{fps}
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#   2⎞                           2 ⎛                        2
# s} ⎠ + 1.16969022244085⋅\sigmaₓ ⋅⎝3.97341653769464⋅\sigmaₓ  + 16.0⋅\tau_\mathr
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2
#                                               \sigmaₓ
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                                                                              2
#       2⎞                    ⎛                         2                    2⎞
# m{fps} ⎠ - 17.3043548549161⋅⎝0.248338533605915⋅\sigmaₓ  + \tau_\mathrm{fps} ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                              ⎞
# ─────────────────────────────⎟
# ___⎞                         ⎟
# ⎞  ⎟                         ⎟
# ⎟  ⎟                         ⎟
# ⎠  ⎟                        2⎟
# ── ⎟ + 4.0⋅\tau_\mathrm{fps} ⎟
#    ⎟                         ⎟
#    ⎠                         ⎠

# %%
get_sigma_z = sp.lambdify((tau_fps, sigma_x),sigma_z.subs(subs_sigma_z).subs(params))
sigma_z.subs(subs_sigma_z).subs(params)
# Out:
#                    ⎛                           2                        2⎞
# -0.462311370003328⋅⎝- 0.993354134423659⋅\sigmaₓ  - 4.0⋅\tau_\mathrm{fps} ⎠
# ───────────────────────────────────────────────────────────────────────────
#                                   \sigmaₓ

# %%
sigma_tt_val = 3

# %%
_, (ax1) = plt.subplots(1, 1, figsize=(6,3))
sig_x = np.linspace(sigma_tt_val - 0.000001,-2*sigma_tt_val,100)
eta = 0.01
tau_xx = eta * sigma_tt_val
th_f = get_theta_f(
    tau_xx,sig_x[:, np.newaxis])
th_0 = get_theta_0(
    tau_xx,sig_x[:, np.newaxis])
ax1.plot(sig_x, th_f/np.pi * 180, color='blue', lw=2 );
ax1.plot(sig_x, th_0/np.pi * 180, color='green', lw=2);
ax1.set_xlabel(r'$\sigma_x$'); ax1.set_ylabel(r'$\theta$')
ax1.legend()
# Out:
# <img src="data:image/png;base64,..." width="600">
# No handles with labels found to put in legend.

# %%
_, (ax1) = plt.subplots(1, 1, figsize=(6,3))
tau_val = np.linspace(0.00001, 0.1, 100)
th_f = get_theta_f(
    tau_val[np.newaxis, :], #row vector
    sig_x[:, np.newaxis]) #column vector
sig_z = get_sigma_z(
    tau_val[np.newaxis, :],
    sig_x[:, np.newaxis])
ax1.plot(th_f, sig_z);
ax1.set_xlabel(r'$\theta$'); ax1.set_ylabel(r'$\sigma_z$')
ax1.legend()
# Out:
# <img src="data:image/png;base64,..." width="600">
# No handles with labels found to put in legend.

# %%
DELTA = np.ones(2)
P_x0_norm = P_x0.norm()
get_P_x0 = sp.lambdify((tau_fps, sigma_x), P_x0, 'numpy')
get_P_xf = sp.lambdify((tau_fps, sigma_x), P_xf.subs(params), 'numpy')
get_D_x0 = sp.lambdify((tau_fps, sigma_x), D_x0, 'numpy')
get_D_xf = sp.lambdify((tau_fps, sigma_x), D_xf.subs(params), 'numpy')
P_x0_norm
# Out:
#        _______________________________________________________________________
#       ╱                                                   2
#      ╱    │              \tau_\mathrm{fps}               │      │
#     ╱   4⋅│──────────────────────────────────────────────│  + 4⋅│─────────────
#    ╱      │             _________________________________│      │
#   ╱       │            ╱        2                      2 │      │            ╱
# ╲╱        │\sigmaₓ - ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}  │      │\sigmaₓ + ╲╱
#
# ________________________________________
#                                   2
#  \tau_\mathrm{fps}               │
# ─────────────────────────────────│  + 2
# _________________________________│
#         2                      2 │
#  \sigmaₓ  + 4⋅\tau_\mathrm{fps}  │

# %%
def get_D_x0_vals(tau_val = 1, sig_val = 2.8):
    D_x0_vals = get_D_x0(tau_val,sig_val)
    D_x0_vct = np.einsum('...i,...ij->...j', DELTA, D_x0_vals)
    return D_x0_vct[np.newaxis,:]

# %%
def get_D_xf_vals(tau_val = 1, sig_val = 2.8):
    D_xf_vals = get_D_xf(tau_val,sig_val)
    D_xf_vct = np.einsum('i,ij->j', DELTA, D_xf_vals)
    return D_xf_vct[np.newaxis,:]

# %%
def get_T_x0_args(tau_val, sig_val): 
    P_x0_vals = get_P_x0(tau_val,sig_val)
    print(P_x0_vals)
    norm_P_x0_vals2 = np.sqrt(np.einsum('ij,ij->j', P_x0_vals, P_x0_vals))
    T_x0 = P_x0_vals / norm_P_x0_vals2
    T_x0_scaled = T_x0 * get_D_x0_vals(tau_val, sig_val)
    T_x0_0 = np.zeros_like(T_x0)
    T_x0_args = np.einsum('ijk->jik', np.array([T_x0_0, T_x0_scaled]))
    return T_x0_args

# %%
def get_T_xf_args(tau_val, sig_val, pos = np.array([[0,0]])): 
    P_xf_vals = get_P_xf(tau_val,sig_val)
    norm_P_xf_vals2 = np.sqrt(np.einsum('ij,ij->j', P_xf_vals, P_xf_vals))
    T_xf = P_xf_vals / norm_P_xf_vals2
    T_xf_scaled = T_xf * get_D_xf_vals(tau_val, sig_val)
    T_xf_0 = np.zeros_like(T_xf)
    T_vxt = np.array([T_xf_0, T_xf_scaled])
    pos_lk = pos
    T_xf_args = pos_lk[:,None,:, None] + T_vxt[None,:,:,:]
    return np.einsum('lijk->jlik', T_xf_args)

# %%
tau_, sig_x_ = 1, 0.1
T_xf_args = get_T_xf_args(2,sig_x_, np.array([[1,0]]))
T_xf_args
# Out:
# array([[[[1.00000000e+00, 1.00000000e+00],
#          [9.54092886e-01, 3.00197216e+00]]],
#
#
#        [[[0.00000000e+00, 0.00000000e+00],
#          [1.24123904e-03, 7.40427594e+01]]]])

# %%
sig_x_ = np.linspace(2.5, -2.5, 4)
sig_z_ = get_sigma_z(tau_,sig_x_)
pos_lk = np.c_[sig_x_, sig_z_]
pos_lk
# Out:
# array([[ 2.5       ,  1.88779547],
#        [ 0.83333333,  2.60179367],
#        [-0.83333333, -2.60179367],
#        [-2.5       , -1.88779547]])

# %%
tau_, sig_x_ = 1, 0.1
T_x0_args = get_T_x0_args(tau_,sig_x_)
T_xf_args = get_T_xf_args(tau_,sig_x_, pos_lk)
fix, ax = plt.subplots(1,1)
ax.plot(*T_x0_args, color='blue');
ax.plot(*T_xf_args.reshape(2,-1,2), color='green');
ax.axis('equal');
# Out:
# [[-0.95124922  1.05124922]
#  [ 1.          1.        ]]
# <img src="data:image/png;base64,..." width="640">
