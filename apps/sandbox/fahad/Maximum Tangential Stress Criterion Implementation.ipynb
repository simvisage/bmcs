# %% [markdown]
# # Maximum Tangential Stress Criterion for Mixed Mode Failure

# %%
# %matplotlib notebook
import sympy as sp
import numpy as np
sp.init_printing()
import matplotlib.pyplot as plt
import ipywidgets as ipw

# %%
r = sp.Symbol('r', nonnegative = True)
theta = sp.Symbol(r'\theta', nonnegative = True)
K_I = sp.Symbol('K_I', nonnegative = True)
K_II = sp.Symbol('K_{II}', nonnegative = True)
T = sp.Symbol('T', nonnegative = True)
sigma_x =  sp.Symbol(r'\sigma_x', nonnegative = True)
sigma_z =  sp.Symbol(r'\sigma_z', nonnegative = True)
tau_fps = sp.Symbol(r'\tau_\mathrm{fps}')
a = sp.Symbol('a', nonnegative = True)
beta = sp.Symbol(r'\beta', nonnegative = True)
tau_fps
# Out:
# \tau_\mathrm{fps}

# %% [markdown]
# ## Representation of Global Stresses
# The stresses in the global co-ordinates are expressed as:
# \begin{align}
# \sigma_{xz} =
# \left[
# \begin{array}{cc}
# \sigma_{xx} & \tau_{xz} \\
# \tau_{zx} & \sigma_{zz}
# \end{array}
# \right] =
# \left[
# \begin{array}{cc}
# \sigma_{x} & \tau^\mathrm{fps} \\
# \tau^\mathrm{fps} & \sigma_{z}
# \end{array}
# \right]
# \end{align}

# %% [markdown]
# In our case $\sigma_z = 0$ as the specimen is uniaxially loaded therefore, the stress will be depicted as follows:
# The stresses in the global co-ordinates are expressed as:
# \begin{align}
# \sigma_{xz} =
# \left[
# \begin{array}{cc}
# \sigma_{xx} & \tau_{xz} \\
# \tau_{zx} & 0
# \end{array}
# \right] =
# \left[
# \begin{array}{cc}
# \sigma_{x} & \tau^\mathrm{fps} \\
# \tau^\mathrm{fps} & 0
# \end{array}
# \right]
# \end{align}
# $\sigma_x, \tau_{fps}, \sigma_z$ represents the stress in x-direction, shear stress in fracture process segment and stress in vertical direction respectively.

# %% [markdown]
# <img src="farfieldstress.png" width="500"/>

# %%
sigma_xz = sp.Matrix([[sigma_x, tau_fps],
                     [tau_fps, 0]])
#sigma_x0 = sigma_xz.subs(sigma_z,0)
sigma_xz#, sigma_x0
# Out:
# ⎡     \sigmaₓ       \tau_\mathrm{fps}⎤
# ⎢                                    ⎥
# ⎣\tau_\mathrm{fps}          0        ⎦

# %%
P_xz, D_xz = sigma_xz.diagonalize()
P_xz, D_xz
# Out:
# ⎛
# ⎜
# ⎜⎡            -2⋅\tau_\mathrm{fps}                            -2⋅\tau_\mathrm{
# ⎜⎢──────────────────────────────────────────────  ────────────────────────────
# ⎜⎢             _________________________________               _______________
# ⎜⎢            ╱        2                      2               ╱        2
# ⎜⎢\sigmaₓ + ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}    \sigmaₓ - ╲╱  \sigmaₓ  + 4⋅\
# ⎜⎢
# ⎜⎣                      1                                               1
# ⎜
# ⎝
#
#                      ⎡             _________________________________
#                      ⎢            ╱        2                      2
# fps}              ⎤  ⎢\sigmaₓ   ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}
# ──────────────────⎥  ⎢─────── - ────────────────────────────────────
# __________________⎥  ⎢   2                       2
#                 2 ⎥, ⎢
# tau_\mathrm{fps}  ⎥  ⎢
#                   ⎥  ⎢
#                   ⎦  ⎢                                                \sigmaₓ
#                      ⎢                      0                         ───────
#                      ⎣                                                   2
#
#                                       ⎤⎞
#                                       ⎥⎟
#                                       ⎥⎟
#               0                       ⎥⎟
#                                       ⎥⎟
#                                       ⎥⎟
#      _________________________________⎥⎟
#     ╱        2                      2 ⎥⎟
#   ╲╱  \sigmaₓ  + 4⋅\tau_\mathrm{fps}  ⎥⎟
# + ────────────────────────────────────⎥⎟
#                    2                  ⎦⎠

# %%
sp.simplify(P_xz* D_xz * P_xz**(-1))
# Out:
# ⎡     \sigmaₓ       \tau_\mathrm{fps}⎤
# ⎢                                    ⎥
# ⎣\tau_\mathrm{fps}          0        ⎦

# %% [markdown]
# ## Representation of Far field stress in terms of Stress Intensity factors
# In this implementation, the far field stresses are represented in  terms of Stress Intensity factors (SIFs) where $K_I$ represents mode I and $K_{II}$ depicts mode II. This terminology of measuring stresses in SIFs for external stress acting in uniaxial direction is shown as:
# \begin{gather*}
# K_I = \sigma_x \sqrt{\pi a}\sin^2 \beta  \\
# K_{II} = \sigma_x \sqrt{\pi a}\sin\beta \cos\beta
# \end{gather*}
# The positive sign of $K_I$ highlights stress as tension where negative sign shows compression. Similarly, negative sign of $K_{II}$ represents stress in opposite direction. $\beta$ represents the angle of crack orientation with respect to the vertical direction and $a$ represents the length of crack as depicted in figure. In the case of pure mode I failure, $\beta$ is $90°$ whereas for failure along pure mode II $\beta = 0°$.

# %% [markdown]
# The figure above shows stresses in the vicinity of crack tip. $\theta$ depicts crack propagation angle and $r$ represents the radius of fracture propagation segment.

# %%
K_I = sigma_x * sp.sqrt(sp.pi * a) * sp.sin(beta)**2
K_II  = sigma_x * sp.sqrt(sp.pi * a) * sp.cos(beta) * sp.sin(beta)
K_I, K_II
# Out:
# ⎛                 2                                            ⎞
# ⎝√π⋅\sigmaₓ⋅√a⋅sin (\beta), √π⋅\sigmaₓ⋅√a⋅sin(\beta)⋅cos(\beta)⎠

# %%
params = {beta:45*np.pi/180}

# %%
K_I_ = K_I.subs(params)
K_II_ = K_II.subs(params)
K_I_, K_II_
# Out:
# (0.5⋅√π⋅\sigmaₓ⋅√a, 0.5⋅√π⋅\sigmaₓ⋅√a)

# %% [markdown]
# ## Maximum Stress Theory
# This theory was given by Sih and Erdogan. It is based on the two dimensional stresses acting on the vicinity of the crack. These stresses are given in the figure below. Moreover, they are represented as:
# \begin{align}
# \label{eq:sigrr}
# \sigma_{rr} &= \frac{1}{\sqrt{2 \pi r}}\left( K_I \left( \cos \frac{\theta}{2}\left(1 + \sin^2 \frac{\theta}{2}\right)\right) + K_{II}\left(\sin \frac{\theta}{2}\left(1 -
# 3 \sin^2 \frac{\theta}{2} \right) \right) \right) + T \cos^2 \theta
# \end{align}
# \begin{align}
# \label{eq:sigtt}
# \sigma_{\theta\theta}
# & = \frac{1}{\sqrt{2 \pi r}}\left( K_I \left( \cos^3 \frac{\theta}{2} \right) - K_{II}\left(3 \sin \frac{\theta}{2} \cos^2 \frac{\theta}{2} \right) \right) + T \sin^2 \theta
# \end{align}
# \begin{align}
# \label{eq:sigtr}
# \sigma_{r\theta}
# & = \frac{1}{\sqrt{2 \pi r}}\left( K_I \left(\sin \frac{\theta}{2} \cos^2 \frac{\theta}{2} \right) + K_{II}\left(\cos \frac{\theta}{2}\left(1 - 3 \sin^2 \frac{\theta}{2} \right) \right) \right) + T \sin \theta \cos \theta
# \end{align}
# For simplicity T-Stress is neglected.

# %%
## Representation of sin and cos components as s_t and c_t for simplicity.
s_t, c_t = sp.symbols('s_t,c_t')
s_t_ = sp.sin(theta + beta.subs(params))
c_t_ = sp.cos(theta + beta.subs(params))
s_t_
# Out:
# sin(\theta + 0.785398163397448)

# %%
sigma_rr = 1/sp.sqrt(2 * sp.pi *r) * (K_I_*c_t*(1 + (s_t)**2) \
                                      + (K_II_*s_t)*(1 - 3*(s_t)**2)) #+ T*(c_t)**2
#s_rr = sigma_rr.subs(c_t, c_t_).subs(s_t, s_t_)
#s_rr
sigma_rr
# Out:
#    ⎛                     ⎛  2    ⎞                        ⎛        2⎞⎞
# √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ⋅⎝sₜ  + 1⎠ + 0.5⋅√π⋅\sigmaₓ⋅√a⋅sₜ⋅⎝1 - 3⋅sₜ ⎠⎠
# ──────────────────────────────────────────────────────────────────────
#                                2⋅√π⋅√r

# %%
sigma_tt = 1/sp.sqrt(2 * sp.pi *r) * (K_I_*(c_t)**3 \
                                      - (K_II_*(3*s_t*(c_t)**2))) #+ T*s_t**2
#s_tt = sigma_tt.subs(c_t, c_t_).subs(s_t, s_t_)
#s_tt
sigma_tt
# Out:
#    ⎛                    3                       2   ⎞
# √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ  - 1.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ ⋅sₜ⎠
# ─────────────────────────────────────────────────────
#                        2⋅√π⋅√r

# %%
sigma_rt = 1/sp.sqrt(2 * sp.pi *r) * ((K_I_*(s_t_*(c_t)**2)) \
                                      + ((K_II_*c_t)*(1 - 3*(s_t)**2))) #+ T*s_t*c_t
#s_rt = sigma_rt.subs(c_t, c_t_).subs(s_t, s_t_)
#s_rt
sigma_rt
# Out:
#    ⎛                    2
# √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ ⋅sin(\theta + 0.785398163397448) + 0.5⋅√π⋅\sigmaₓ⋅√a⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                            2⋅√π⋅√r
#
#    ⎛        2⎞⎞
# cₜ⋅⎝1 - 3⋅sₜ ⎠⎠
# ───────────────

# %% [markdown]
# The stresses in the vicinity of the crack will be represented by tensorial representation as:
#
# \begin{align}
# \sigma =
# \left[
# \begin{array}{cc}
# \sigma_{rr} & \tau_{rt} \\
# \tau_{rt} & \sigma_{tt}
# \end{array}
# \right]
# \end{align}

# %%
sigma = sp.Matrix([[sigma_rr, sigma_rt],
                     [sigma_rt, sigma_tt]])
sigma
# Out:
# ⎡              ⎛                     ⎛  2    ⎞                        ⎛
# ⎢           √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ⋅⎝sₜ  + 1⎠ + 0.5⋅√π⋅\sigmaₓ⋅√a⋅sₜ⋅⎝1 - 3⋅s
# ⎢           ──────────────────────────────────────────────────────────────────
# ⎢                                          2⋅√π⋅√r
# ⎢
# ⎢   ⎛                    2
# ⎢√2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ ⋅sin(\theta + 0.785398163397448) + 0.5⋅√π⋅\sigmaₓ⋅√a
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎣                                           2⋅√π⋅√r
#
#  2⎞⎞                 ⎛                    2
# ₜ ⎠⎠              √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ ⋅sin(\theta + 0.785398163397448) +
# ────              ────────────────────────────────────────────────────────────
#                                                              2⋅√π⋅√r
#
#     ⎛        2⎞⎞                         ⎛                    3
# ⋅cₜ⋅⎝1 - 3⋅sₜ ⎠⎠                      √2⋅⎝0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ  - 1.5⋅√π⋅\sigm
# ────────────────                      ────────────────────────────────────────
#                                                              2⋅√π⋅√r
#
#                      ⎛        2⎞⎞⎤
# 0.5⋅√π⋅\sigmaₓ⋅√a⋅cₜ⋅⎝1 - 3⋅sₜ ⎠⎠⎥
# ─────────────────────────────────⎥
#                                  ⎥
#                                  ⎥
#         2   ⎞                    ⎥
# aₓ⋅√a⋅cₜ ⋅sₜ⎠                    ⎥
# ─────────────                    ⎥
#                                  ⎦

# %%
R = sp.Matrix([[c_t_, -s_t_],
              [s_t_,   c_t_]])
R, R.T
# Out:
# ⎛⎡cos(\theta + 0.785398163397448)  -sin(\theta + 0.785398163397448)⎤  ⎡cos(\th
# ⎜⎢                                                                 ⎥, ⎢
# ⎝⎣sin(\theta + 0.785398163397448)  cos(\theta + 0.785398163397448) ⎦  ⎣-sin(\t
#
# eta + 0.785398163397448)   sin(\theta + 0.785398163397448)⎤⎞
#                                                           ⎥⎟
# heta + 0.785398163397448)  cos(\theta + 0.785398163397448)⎦⎠

# %%
s_t1 = sp.sin(theta) / 2
c_t1 = sp.cos(theta) / 2
s = sigma.subs(s_t,s_t1).subs(c_t,c_t1)
sigma_ = R * s * R.T #.subs(s_t,s_t_).subs(c_t,c_t_) #transformation into global stress matrix
sig = sp.simplify(sigma_) 
sig
# Out:
# ⎡              ⎛   ⎛
# ⎢√2⋅\sigmaₓ⋅√a⋅⎝cₜ⋅⎝cₜ⋅(cₜ⋅sin(\beta) - 3⋅sₜ⋅cos(\beta))⋅sin(\beta + \theta) -
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢              ⎛     ⎛
# ⎢√2⋅\sigmaₓ⋅√a⋅⎝- cₜ⋅⎝cₜ⋅(cₜ⋅sin(\beta) - 3⋅sₜ⋅cos(\beta))⋅cos(\beta + \theta)
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎣
#
#  ⎛                                    ⎛        2⎞           ⎞
#  ⎝cₜ⋅sin(\beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅sₜ ⎠⋅cos(\beta)⎠⋅cos(\beta + \the
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    ⎛                                    ⎛        2⎞           ⎞
#  + ⎝cₜ⋅sin(\beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅sₜ ⎠⋅cos(\beta)⎠⋅sin(\beta + \t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    ⎞                       ⎛     ⎛                                    ⎛
# ta)⎠⋅sin(\beta + \theta) + ⎝- cₜ⋅⎝cₜ⋅sin(\beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅s
# ──────────────────────────────────────────────────────────────────────────────
#                                 2⋅√r
#
#      ⎞                       ⎛   ⎛                                    ⎛
# heta)⎠⋅sin(\beta + \theta) + ⎝cₜ⋅⎝cₜ⋅sin(\beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅s
# ──────────────────────────────────────────────────────────────────────────────
#                                 2⋅√r
#
#  2⎞           ⎞                       ⎛   ⎛  2    ⎞                 ⎛    2
# ₜ ⎠⋅cos(\beta)⎠⋅sin(\beta + \theta) + ⎝cₜ⋅⎝sₜ  + 1⎠⋅sin(\beta) - sₜ⋅⎝3⋅sₜ  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  2⎞           ⎞                       ⎛   ⎛  2    ⎞                 ⎛    2
# ₜ ⎠⋅cos(\beta)⎠⋅cos(\beta + \theta) + ⎝cₜ⋅⎝sₜ  + 1⎠⋅sin(\beta) - sₜ⋅⎝3⋅sₜ  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⎞           ⎞                    ⎞                    ⎞
# ⎠⋅cos(\beta)⎠⋅cos(\beta + \theta)⎠⋅cos(\beta + \theta)⎠⋅sin(\beta)  √2⋅\sigmaₓ
# ──────────────────────────────────────────────────────────────────  ──────────
#
#
# ⎞           ⎞                    ⎞                    ⎞
# ⎠⋅cos(\beta)⎠⋅sin(\beta + \theta)⎠⋅cos(\beta + \theta)⎠⋅sin(\beta)    √2⋅\sigm
# ──────────────────────────────────────────────────────────────────    ────────
#
#
#     ⎛     ⎛                                                           ⎛
# ⋅√a⋅⎝- cₜ⋅⎝cₜ⋅(cₜ⋅sin(\beta) - 3⋅sₜ⋅cos(\beta))⋅sin(\beta + \theta) - ⎝cₜ⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       ⎛   ⎛                                                           ⎛
# aₓ⋅√a⋅⎝cₜ⋅⎝cₜ⋅(cₜ⋅sin(\beta) - 3⋅sₜ⋅cos(\beta))⋅cos(\beta + \theta) + ⎝cₜ⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                              ⎛        2⎞           ⎞                    ⎞
# \beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅sₜ ⎠⋅cos(\beta)⎠⋅cos(\beta + \theta)⎠⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                              ⎛        2⎞           ⎞                    ⎞
# \beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅sₜ ⎠⋅cos(\beta)⎠⋅sin(\beta + \theta)⎠⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                   ⎛     ⎛                                    ⎛        2⎞
# \beta + \theta) + ⎝- cₜ⋅⎝cₜ⋅sin(\beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅sₜ ⎠⋅cos(\
# ──────────────────────────────────────────────────────────────────────────────
#                       2⋅√r
#
#                   ⎛   ⎛                                    ⎛        2⎞
# \beta + \theta) + ⎝cₜ⋅⎝cₜ⋅sin(\beta)⋅sin(\beta + \theta) + ⎝1 - 3⋅sₜ ⎠⋅cos(\be
# ──────────────────────────────────────────────────────────────────────────────
#                       2⋅√r
#
#      ⎞                       ⎛   ⎛  2    ⎞                 ⎛    2    ⎞
# beta)⎠⋅sin(\beta + \theta) + ⎝cₜ⋅⎝sₜ  + 1⎠⋅sin(\beta) - sₜ⋅⎝3⋅sₜ  - 1⎠⋅cos(\be
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    ⎞                       ⎛   ⎛  2    ⎞                 ⎛    2    ⎞
# ta)⎠⋅cos(\beta + \theta) + ⎝cₜ⋅⎝sₜ  + 1⎠⋅sin(\beta) - sₜ⋅⎝3⋅sₜ  - 1⎠⋅cos(\beta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    ⎞                    ⎞                    ⎞           ⎤
# ta)⎠⋅cos(\beta + \theta)⎠⋅sin(\beta + \theta)⎠⋅sin(\beta)⎥
# ─────────────────────────────────────────────────────────⎥
#                                                          ⎥
#                                                          ⎥
#  ⎞                    ⎞                    ⎞             ⎥
# )⎠⋅sin(\beta + \theta)⎠⋅sin(\beta + \theta)⎠⋅sin(\beta)  ⎥
# ───────────────────────────────────────────────────────  ⎥
#                                                          ⎦

# %%
P_rt, D_rt = sig.diagonalize()
P_rt, D_rt;
#s_t_ = sp.sin(theta + beta.subs(params))
#c_t_ = sp.cos(theta + beta.subs(params))
#s_t_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-861cef887e6b> in <module>
# ----> 1 P_rt, D_rt = sig.diagonalize()
#       2 P_rt, D_rt;
#       3 #s_t_ = sp.sin(theta + beta.subs(params))
#       4 #c_t_ = sp.cos(theta + beta.subs(params))
#       5 #s_t_
#
# ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py in diagonalize(self, reals_only, sort, normalize)
#    1164             raise NonSquareMatrixError()
#    1165
# -> 1166         if not self.is_diagonalizable(reals_only=reals_only):
#    1167             raise MatrixError("Matrix is not diagonalizable")
#    1168
#
# ~\anaconda3\lib\site-packages\sympy\matrices\immutable.py in is_diagonalizable(self, reals_only, **kwargs)
#     116     def is_diagonalizable(self, reals_only=False, **kwargs):
#     117         return super(ImmutableDenseMatrix, self).is_diagonalizable(
# --> 118             reals_only=reals_only, **kwargs)
#     119     is_diagonalizable.__doc__ = DenseMatrix.is_diagonalizable.__doc__
#     120     is_diagonalizable = cacheit(is_diagonalizable)
#
# ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py in is_diagonalizable(self, reals_only, **kwargs)
#    1471             return True
#    1472
# -> 1473         eigenvecs = self.eigenvects(simplify=True)
#    1474
#    1475         ret = True
#
# ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py in eigenvects(self, error_when_incomplete, iszerofunc, **flags)
#    1386         eigenvals = mat.eigenvals(rational=False,
#    1387                                   error_when_incomplete=error_when_incomplete,
# -> 1388                                   **flags)
#    1389         ret = [(val, mult, eigenspace(val)) for val, mult in
#    1390                     sorted(eigenvals.items(), key=default_sort_key)]
#
# ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py in eigenvals(self, error_when_incomplete, **flags)
#    1276                 eigs = roots(mat.charpoly(x=Dummy('x'), simplify=simplify), **flags)
#    1277             else:
# -> 1278                 eigs = roots(mat.charpoly(x=Dummy('x')), **flags)
#    1279
#    1280         # make sure the algebraic multiplicity sums to the
#
# ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py in charpoly(self, x, simplify)
#     346         berk_vector = self._eval_berkowitz_vector()
#     347         x = _uniquely_named_symbol(x, berk_vector)
# --> 348         return PurePoly([simplify(a) for a in berk_vector], x)
#     349
#     350     def cofactor(self, i, j, method="berkowitz"):
#
# ~\anaconda3\lib\site-packages\sympy\matrices\matrices.py in <listcomp>(.0)
#     346         berk_vector = self._eval_berkowitz_vector()
#     347         x = _uniquely_named_symbol(x, berk_vector)
# --> 348         return PurePoly([simplify(a) for a in berk_vector], x)
#     349
#     350     def cofactor(self, i, j, method="berkowitz"):
#
# ~\anaconda3\lib\site-packages\sympy\simplify\simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     654
#     655     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 656         expr = trigsimp(expr, deep=True)
#     657
#     658     if expr.has(log):
#
# ~\anaconda3\lib\site-packages\sympy\simplify\trigsimp.py in trigsimp(expr, **opts)
#     506                    }[method]
#     507
# --> 508     return trigsimpfunc(expr)
#     509
#     510
#
# ~\anaconda3\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#     499     trigsimpfunc = {
#     500         'fu': (lambda x: fu(x, **opts)),
# --> 501         'matching': (lambda x: futrig(x)),
#     502         'groebner': (lambda x: groebnersimp(x, **opts)),
#     503         'combined': (lambda x: futrig(groebnersimp(x,
#
# ~\anaconda3\lib\site-packages\sympy\simplify\trigsimp.py in futrig(e, **kwargs)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# ~\anaconda3\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~\anaconda3\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~\anaconda3\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~\anaconda3\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# ~\anaconda3\lib\site-packages\sympy\simplify\trigsimp.py in _futrig(e, **kwargs)
#    1167             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1168         )]
# -> 1169     e = greedy(tree, objective=Lops)(e)
#    1170     return coeff*e
#    1171
#
# ~\anaconda3\lib\site-packages\sympy\strategies\core.py in minrule(expr)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# ~\anaconda3\lib\site-packages\sympy\strategies\core.py in <listcomp>(.0)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# ~\anaconda3\lib\site-packages\sympy\strategies\core.py in chain_rl(expr)
#      42     def chain_rl(expr):
#      43         for rule in rules:
# ---> 44             expr = rule(expr)
#      45         return expr
#      46     return chain_rl
#
# ~\anaconda3\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#    1144         TR10,  # sin-cos of sums -> sin-cos prod
#    1145         TR11, TR6, # reduce double angles and rewrite cos pows
# -> 1146         lambda x: _eapply(factor, x, trigs),
#    1147         TR14,  # factored powers of identities
#    1148         [identity, lambda x: _eapply(_mexpand, x, trigs)],
#
# ~\anaconda3\lib\site-packages\sympy\simplify\trigsimp.py in _eapply(func, e, cond)
#    1188         return e
#    1189     if _is_Expr(e) or not e.args:
# -> 1190         return func(e)
#    1191     return e.func(*[
#    1192         _eapply(func, ei) if (cond is None or cond(ei)) else ei
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in factor(f, *gens, **args)
#    6350
#    6351     try:
# -> 6352         return _generic_factor(f, gens, args, method='factor')
#    6353     except PolynomialError as msg:
#    6354         if not f.is_commutative:
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in _generic_factor(expr, gens, args, method)
#    6022     opt = options.build_options(gens, args)
#    6023     opt['fraction'] = fraction
# -> 6024     return _symbolic_factor(sympify(expr), opt, method)
#    6025
#    6026
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in _symbolic_factor(expr, opt, method)
#    5965         if hasattr(expr,'_eval_factor'):
#    5966             return expr._eval_factor()
# -> 5967         coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    5968         return _keep_coeff(coeff, _factors_product(factors))
#    5969     elif hasattr(expr, 'args'):
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in _symbolic_factor_list(expr, opt, method)
#    5933             func = getattr(poly, method + '_list')
#    5934
# -> 5935             _coeff, _factors = func()
#    5936             if _coeff is not S.One:
#    5937                 if exp.is_Integer:
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in factor_list(f)
#    3238         if hasattr(f.rep, 'factor_list'):
#    3239             try:
# -> 3240                 coeff, factors = f.rep.factor_list()
#    3241             except DomainError:
#    3242                 return S.One, [(f, 1)]
#
# ~\anaconda3\lib\site-packages\sympy\polys\polyclasses.py in factor_list(f)
#     794     def factor_list(f):
#     795         """Returns a list of irreducible factors of ``f``. """
# --> 796         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     797         return coeff, [ (f.per(g), k) for g, k in factors ]
#     798
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_factor_list(f, u, K0)
#    1287         if K.is_ZZ:
#    1288             levels, f, v = dmp_exclude(f, u, K)
# -> 1289             coeff, factors = dmp_zz_factor(f, v, K)
#    1290
#    1291             for i, (f, k) in enumerate(factors):
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_factor(f, u, K)
#    1098     if dmp_degree(g, u) > 0:
#    1099         g = dmp_sqf_part(g, u, K)
# -> 1100         H = dmp_zz_wang(g, u, K)
#    1101         factors = dmp_trial_division(f, H, u, K)
#    1102
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_wang(f, u, K, mod, seed)
#     934     randint = _randint(seed)
#     935
# --> 936     ct, T = dmp_zz_factor(dmp_LC(f, K), u - 1, K)
#     937
#     938     b = dmp_zz_mignotte_bound(f, u, K)
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_factor(f, u, K)
#    1098     if dmp_degree(g, u) > 0:
#    1099         g = dmp_sqf_part(g, u, K)
# -> 1100         H = dmp_zz_wang(g, u, K)
#    1101         factors = dmp_trial_division(f, H, u, K)
#    1102
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_wang(f, u, K, mod, seed)
#    1021     try:
#    1022         f, H, LC = dmp_zz_wang_lead_coeffs(f, T, cs, E, H, A, u, K)
# -> 1023         factors = dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#    1024     except ExtraneousFactors:  # pragma: no cover
#    1025         if query('EEZ_RESTART_IF_NEEDED'):
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#     885             if not dmp_zero_p(C, w - 1):
#     886                 C = dmp_quo_ground(C, K.factorial(k + 1), w - 1, K)
# --> 887                 T = dmp_zz_diophantine(G, C, I, d, p, w - 1, K)
#     888
#     889                 for i, (h, t) in enumerate(zip(H, T)):
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     810         v = u - 1
#     811
# --> 812         S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     813         S = [ dmp_raise(s, 1, v, K) for s in S ]
#     814
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     810         v = u - 1
#     811
# --> 812         S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     813         S = [ dmp_raise(s, 1, v, K) for s in S ]
#     814
#
# ~\anaconda3\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     803
#     804         for f in F:
# --> 805             B.append(dmp_quo(e, f, u, K))
#     806             G.append(dmp_eval_in(f, a, n, u, K))
#     807
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_quo(f, g, u, K)
#    1671
#    1672     """
# -> 1673     return dmp_div(f, g, u, K)[0]
#    1674
#    1675
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_div(f, g, u, K)
#    1629         return dmp_ff_div(f, g, u, K)
#    1630     else:
# -> 1631         return dmp_rr_div(f, g, u, K)
#    1632
#    1633
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1389     while True:
#    1390         lc_r = dmp_LC(r, K)
# -> 1391         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1392
#    1393         if not dmp_zero_p(R, v):
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1398         q = dmp_add_term(q, c, j, u, K)
#    1399         h = dmp_mul_term(g, c, j, u, K)
# -> 1400         r = dmp_sub(r, h, u, K)
#    1401
#    1402         _dr, dr = dr, dmp_degree(r, u)
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     655
#     656     if df == dg:
# --> 657         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     658     else:
#     659         k = abs(df - dg)
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     655
#     656     if df == dg:
# --> 657         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     658     else:
#     659         k = abs(df - dg)
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     655
#     656     if df == dg:
# --> 657         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     658     else:
#     659         k = abs(df - dg)
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     655
#     656     if df == dg:
# --> 657         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     658     else:
#     659         k = abs(df - dg)
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     640     """
#     641     if not u:
# --> 642         return dup_sub(f, g, K)
#     643
#     644     df = dmp_degree(f, u)
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in dup_sub(f, g, K)
#     613
#     614     if df == dg:
# --> 615         return dup_strip([ a - b for a, b in zip(f, g) ])
#     616     else:
#     617         k = abs(df - dg)
#
# ~\anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     613
#     614     if df == dg:
# --> 615         return dup_strip([ a - b for a, b in zip(f, g) ])
#     616     else:
#     617         k = abs(df - dg)
#
# KeyboardInterrupt:

# %%
sp.simplify(P_rt * D_rt * P_rt**(-1));

# %%
D = sp.expand_trig(D_rt)
D;

# %%
params = {a:15, r:3, c_t: 0.866, T:5, s_t:0.5} #theta: 0.52}

# %%
theta_ = sp.atan( sp.simplify(P_rt[0,0] / P_rt[1,0]))
theta_

# %%
get_theta_ = sp.lambdify((theta), theta_.subs(params))
theta_.subs(params)

# %%
#sigma_tt_val = 3

# %%
# _, (ax1) = plt.subplots(1, 1, figsize=(6,3))
# sig_x = np.linspace(sigma_tt_val - 0.000001,-2*sigma_tt_val,100)
# eta = 0.01
# tau_xx = eta * sigma_tt_val
# th_f = get_theta_(
#     tau_xx,sig_x[:, np.newaxis])
# ax1.plot(sig_x, th_f/np.pi * 180, color='blue', lw=2 );
# ax1.set_xlabel(r'$\sigma_x$'); ax1.set_ylabel(r'$\theta$')
# ax1.legend()

# %%
# _, (ax1) = plt.subplots(1, 1, figsize=(6,3))
# tau_val = np.linspace(0.00001, 0.1, 100)
# th_f = get_theta_f(
#     tau_val[np.newaxis, :], #row vector
#     sig_x[:, np.newaxis]) #column vector
# sig_z = get_sigma_z(
#     tau_val[np.newaxis, :],
#     sig_x[:, np.newaxis])
# ax1.plot(th_f, sig_z);
# ax1.set_xlabel(r'$\theta$'); ax1.set_ylabel(r'$\sigma_z$')
# ax1.legend()

# %%
# DELTA = np.ones(2)
# P_x0_norm = P_x0.norm()
# get_P_x0 = sp.lambdify((tau_fps, sigma_x), P_x0, 'numpy')
# get_P_xf = sp.lambdify((tau_fps, sigma_x), P_xf.subs(params), 'numpy')
# get_D_x0 = sp.lambdify((tau_fps, sigma_x), D_x0, 'numpy')
# get_D_xf = sp.lambdify((tau_fps, sigma_x), D_xf.subs(params), 'numpy')
# P_x0_norm

# %%
# def get_D_x0_vals(tau_val = 1, sig_val = 2.8):
#     D_x0_vals = get_D_x0(tau_val,sig_val)
#     D_x0_vct = np.einsum('...i,...ij->...j', DELTA, D_x0_vals)
#     return D_x0_vct[np.newaxis,:]

# %%
# def get_D_xf_vals(tau_val = 1, sig_val = 2.8):
#     D_xf_vals = get_D_xf(tau_val,sig_val)
#     D_xf_vct = np.einsum('i,ij->j', DELTA, D_xf_vals)
#     return D_xf_vct[np.newaxis,:]

# %%
# def get_T_x0_args(tau_val, sig_val): 
#     P_x0_vals = get_P_x0(tau_val,sig_val)
#     print(P_x0_vals)
#     norm_P_x0_vals2 = np.sqrt(np.einsum('ij,ij->j', P_x0_vals, P_x0_vals)) #element wise multiplication and sum along j?
#     T_x0 = P_x0_vals / norm_P_x0_vals2
#     T_x0_scaled = T_x0 * get_D_x0_vals(tau_val, sig_val)
#     T_x0_0 = np.zeros_like(T_x0)
#     T_x0_args = np.einsum('ijk->jik', np.array([T_x0_0, T_x0_scaled]))
#     return T_x0_args

# %%
# def get_T_xf_args(tau_val, sig_val, pos = np.array([[0,0]])): 
#     P_xf_vals = get_P_xf(tau_val,sig_val)
#     norm_P_xf_vals2 = np.sqrt(np.einsum('ij,ij->j', P_xf_vals, P_xf_vals))
#     T_xf = P_xf_vals / norm_P_xf_vals2
#     T_xf_scaled = T_xf * get_D_xf_vals(tau_val, sig_val)
#     T_xf_0 = np.zeros_like(T_xf)
#     T_vxt = np.array([T_xf_0, T_xf_scaled])
#     pos_lk = pos
#     T_xf_args = pos_lk[:,None,:, None] + T_vxt[None,:,:,:] #???
#     return np.einsum('lijk->jlik', T_xf_args)

# %%
# tau_, sig_x_ = 1, 0.1
# T_xf_args = get_T_xf_args(2,sig_x_, np.array([[1,0]]))
# T_xf_args

# %%
# sig_x_ = np.linspace(2.5, -2.5, 4)
# sig_z_ = get_sigma_z(tau_,sig_x_)
# pos_lk = np.c_[sig_x_, sig_z_]
# pos_lk

# %%
# tau_, sig_x_ = 1, 0.1
# T_x0_args = get_T_x0_args(tau_,sig_x_)
# T_xf_args = get_T_xf_args(tau_,sig_x_, pos_lk)
# fix, ax = plt.subplots(1,1)
# ax.plot(*T_x0_args, color='blue');
# ax.plot(*T_xf_args.reshape(2,-1,2), color='green');
# ax.axis('equal');
